# %% [markdown]
# # Import Libraries

# %%
import os
import json
import csv
import random
from pathlib import Path

# Data Science & Visualization
import numpy as np
import pandas as pd  # Often useful with CSVs
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Computer Vision
import cv2

# Scikit-Learn (Metrics & Preprocessing)
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, 
    roc_auc_score, roc_curve, auc, confusion_matrix, 
    classification_report, mean_absolute_error, 
    mean_squared_error, r2_score
)

# TensorFlow & Keras
import tensorflow as tf
from tensorflow.keras import layers, models, Input, Model, regularizers
from tensorflow.keras.applications import ResNet50, MobileNetV2
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import Dense, Flatten, Concatenate, Layer

# %% [markdown]
# # WHO Threshold

# %%
def get_anemia_label(age, gender, hb):
    """
    WHO 4-class anemia classification.
    gender : 1=Male, 0=Female
    age    : in years
    hb     : hemoglobin in g/dL
    Returns: 0=Non-Anemic, 1=Mild, 2=Moderate, 3=Severe
             -1=Not applicable (ages 5-14 and 65+)
    """
    if age < 5:                          # < 59 months (~5 years)
        if   hb >= 11.0: return 0        # Non-Anemic
        elif hb >= 10.0: return 1        # Mild
        elif hb >= 7.0:  return 2        # Moderate
        else:            return 3        # Severe

    elif 15 <= age <= 65:
        if gender == 0:                  # Non-Pregnant Women
            if   hb >= 12.0: return 0
            elif hb >= 11.0: return 1
            elif hb >= 8.0:  return 2
            else:            return 3
        else:                            # Men
            if   hb >= 13.0: return 0
            elif hb >= 11.0: return 1
            elif hb >= 8.0:  return 2
            else:            return 3

    else:
        return -1                        # Ages 5-14 and 65+ — exclude from dataset

# %% [markdown]
# # Data Prepration

# %% [markdown]
# ## Data Loading

# %%
Dataset_path = "Data" 
IMG_SIZE = 224

# %%
def load_dataset(Dataset_path):
    X_palm, X_nail, X_meta = [], [], []
    y_hb                    = []
    subject_ids             = []

    root     = Path(Dataset_path)
    subjects = [p for p in root.iterdir() if p.is_dir()]

    for s in subjects:
        json_path = s / "info.json"
        if not json_path.exists():
            continue
        with open(json_path, "r") as f:
            info = json.load(f)

        age    = info["age"]
        gender = 1 if info["gender"] == "Male" else 0
        hb     = float(info["HB_Level"])

        # Palm ROI
        palm_path = s / "Palm_ROI" / "frame_03.jpg"
        if not palm_path.exists():
            continue
        palm_img = cv2.imread(str(palm_path))
        if palm_img is None:
            continue
        palm_img = cv2.cvtColor(palm_img, cv2.COLOR_BGR2RGB)
        palm_img = cv2.resize(palm_img, (IMG_SIZE, IMG_SIZE))
        palm_img = palm_img / 255.0

        # Nail ROI + background removal
        nail_path = s / "nail_roi.jpg"
        if not nail_path.exists():
            continue
        nail_img = cv2.imread(str(nail_path))
        if nail_img is None:
            continue
        
        nail_img = cv2.cvtColor(nail_img, cv2.COLOR_BGR2RGB)
        nail_img = cv2.resize(nail_img, (IMG_SIZE, IMG_SIZE))
        nail_img = nail_img / 255.0

        X_palm.append(palm_img)
        X_nail.append(nail_img)
        X_meta.append([age, gender])
        y_hb.append(hb)
        subject_ids.append(s.name)

    return (
        np.array(X_palm,  dtype=np.float32),
        np.array(X_nail,  dtype=np.float32),
        np.array(X_meta,  dtype=np.float32),
        np.array(y_hb,    dtype=np.float32),
        np.array(subject_ids)
    )

# %%
X_palm, X_nail, X_meta, y_hb, subject_ids = load_dataset(Dataset_path)

# %%
X_meta_original = X_meta.copy()

# %%
X_meta[:, 0] = (X_meta[:, 0] - X_meta[:, 0].mean()) / X_meta[:, 0].std()

# %%
y_label = np.array([
    get_anemia_label(X_meta_original[i, 0], X_meta_original[i, 1], y_hb[i])
    for i in range(len(subject_ids))
], dtype=np.int32)

print(f"Total patients : {len(subject_ids)}")
print(f"Non-Anemic (0) : {sum(y_label == 0)}")
print(f"Mild (1)       : {sum(y_label == 1)}")
print(f"Moderate (2)   : {sum(y_label == 2)}")
print(f"Severe (3)     : {sum(y_label == 3)}")
print(f"Excluded (-1)  : {sum(y_label == -1)}")
# Out:
# Total patients : 527
# Non-Anemic (0) : 263
# Mild (1)       : 192
# Moderate (2)   : 72
# Severe (3)     : 0
# Excluded (-1)  : 0

# %% [markdown]
# ## Data Split

# %%
unique_subjects = np.unique(subject_ids)

# still stratify by anemia class just to keep HB distribution balanced
unique_labels = np.array([
    0 if y_hb[subject_ids == s][0] >= 12.0 else 1 
    for s in unique_subjects
])

train_subj, temp_subj = train_test_split(
    unique_subjects, test_size=0.30, random_state=42, stratify=unique_labels
)
temp_labels = np.array([
    0 if y_hb[subject_ids == s][0] >= 12.0 else 1 
    for s in temp_subj
])
val_subj, test_subj = train_test_split(
    temp_subj, test_size=0.50, random_state=42, stratify=temp_labels
)

train_idx = np.where(np.isin(subject_ids, train_subj))[0]
val_idx   = np.where(np.isin(subject_ids, val_subj))[0]
test_idx  = np.where(np.isin(subject_ids, test_subj))[0]

X_palm_train, X_palm_val, X_palm_test = X_palm[train_idx], X_palm[val_idx], X_palm[test_idx]
X_nail_train, X_nail_val, X_nail_test = X_nail[train_idx], X_nail[val_idx], X_nail[test_idx]
X_meta_train, X_meta_val, X_meta_test = X_meta[train_idx], X_meta[val_idx], X_meta[test_idx]
y_hb_train, y_hb_val, y_hb_test       = y_hb[train_idx],   y_hb[val_idx],   y_hb[test_idx]

print(f"\nTrain : {len(train_subj)} patients | HB range: {y_hb_train.min():.1f} — {y_hb_train.max():.1f}")
print(f"Val   : {len(val_subj)}   patients | HB range: {y_hb_val.min():.1f} — {y_hb_val.max():.1f}")
print(f"Test  : {len(test_subj)}  patients | HB range: {y_hb_test.min():.1f} — {y_hb_test.max():.1f}")
# Out:
# Train : 368 patients | HB range: 8.6 — 17.0
# Val   : 79   patients | HB range: 9.6 — 16.4
# Test  : 80  patients | HB range: 10.3 — 15.9

# %% [markdown]
# ## Data Augmentation

# %%
from Augmentation import augment_training_set, augment_image

# %%
print("\nBefore Augmentation:")
print(f"  Train size  : {len(y_hb_train)}")

X_palm_train, X_nail_train, X_meta_train, y_hb_train = augment_training_set(X_palm_train, X_nail_train, X_meta_train, y_hb_train ) # pass y_hb instead of y_label)

print(f"\nAfter Augmentation (1 original + 4 fixed augmentations):")
print(f"  Train size  : {len(y_hb_train)}")
print(f"Val  size     : {len(y_hb_val)}")
print(f"Test size     : {len(y_hb_test)}")
# Out:
# Before Augmentation:
#   Train size  : 368
#
# After Augmentation (1 original + 4 fixed augmentations):
#   Train size  : 1840
# Val  size     : 79
# Test size     : 80

# %%
def visualise_one_sample(X_palm, X_nail, idx=None):
    if idx is None:
        idx = np.random.randint(0, len(X_palm))
    
    img_palm = (X_palm[idx] * 255).astype(np.uint8)
    img_nail = (X_nail[idx] * 255).astype(np.uint8)
    
    titles = ['Original', 'Flip', 'Rotation (15°)', 'Brightness (×1.2)', 'Contrast (×1.2)']
    
    palm_imgs = [img_palm] + [(a * 255).astype(np.uint8) for a in augment_image(X_palm[idx])]
    nail_imgs = [img_nail] + [(a * 255).astype(np.uint8) for a in augment_image(X_nail[idx])]
    
    fig, axes = plt.subplots(2, 5, figsize=(18, 7))
    fig.suptitle(f'Sample {idx} — All Augmentations', fontsize=14, fontweight='bold')
    
    for col in range(5):
        axes[0, col].imshow(palm_imgs[col])
        axes[0, col].set_title(titles[col], fontsize=10)
        axes[0, col].axis('off')
        
        axes[1, col].imshow(nail_imgs[col])
        axes[1, col].set_title(titles[col], fontsize=10)
        axes[1, col].axis('off')
    
    axes[0, 0].set_ylabel('Palm', fontsize=11, fontweight='bold')
    axes[1, 0].set_ylabel('Nail', fontsize=11, fontweight='bold')
    
    plt.tight_layout()
    plt.show()

visualise_one_sample(X_palm_train, X_nail_train)

# %% [markdown]
# # Training Stratergies

# %%
import importlib
import Backbones, Attention, Build

importlib.reload(Backbones)
importlib.reload(Attention)
importlib.reload(Build)

from Build import build_models

# %%
# Regression Tasks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_mae",
        patience=10,
        mode="min",
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_mae",
        patience=5,
        mode="min",
        factor=0.5,
        min_lr=1e-6
    )
]

# %%
def evaluate_regression_model(name, model, history):

    # ── Scores ───────────────────────────────────────────────────
    val_scores  = model.evaluate([X_palm_val,  X_nail_val,  X_meta_val],  y_hb_val,  verbose=0)
    test_scores = model.evaluate([X_palm_test, X_nail_test, X_meta_test], y_hb_test, verbose=0)

    print(f"{name}")
    print(f"{'Metric':<20} {'Validation':>12} {'Test':>10}")
    print(f"{'Loss (MSE)':<20} {val_scores[0]:>12.4f} {test_scores[0]:>10.4f}")
    print(f"{'MAE':<20} {val_scores[1]:>12.4f} {test_scores[1]:>10.4f}")
    print(f"{'RMSE':<20} {val_scores[2]:>12.4f} {test_scores[2]:>10.4f}")

    # ── Predictions ──────────────────────────────────────────────
    y_hb_pred = model.predict([X_palm_test, X_nail_test, X_meta_test], verbose=0).ravel()
    r2        = r2_score(y_hb_test, y_hb_pred)
    print(f"{'R²':<20} {'':>12} {r2:>10.4f}")

    # ── Plots ────────────────────────────────────────────────────
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle(name, fontsize=14, fontweight="bold")

    # Plot 1 - MAE curve
    axes[0].plot(history.history["val_mae"], label="val_mae")
    axes[0].plot(history.history["mae"],     label="train_mae")
    axes[0].set_title("MAE Curve")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MAE (g/dL)")
    axes[0].legend()
    axes[0].grid(True)

    # Plot 2 - Loss curve
    axes[1].plot(history.history["val_loss"], label="val_loss")
    axes[1].plot(history.history["loss"],     label="train_loss")
    axes[1].set_title("Loss Curve")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("MSE")
    axes[1].legend()
    axes[1].grid(True)

    # Plot 3 - Predicted vs Actual HB scatter
    axes[2].scatter(y_hb_test, y_hb_pred, alpha=0.6, color="steelblue")
    axes[2].plot([y_hb_test.min(), y_hb_test.max()],
                 [y_hb_test.min(), y_hb_test.max()],
                 "r--", lw=2, label="Perfect prediction")
    axes[2].set_title(f"Predicted vs Actual HB\n(R²={r2:.3f})")
    axes[2].set_xlabel("Actual HB (g/dL)")
    axes[2].set_ylabel("Predicted HB (g/dL)")
    axes[2].legend()
    axes[2].grid(True)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Models - Experimentation

# %% [markdown]
# ## CNN

# %%
model_1_REG = build_models(backbone="cnn1",mode="regression")

# %%
model_1_REG.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss      = "mse",
    metrics   = [
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.RootMeanSquaredError(name="rmse")
    ]
)

history_1_REG = model_1_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train,       # ← HB values not labels
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val),  # ← y_hb_val
    epochs          = 100,
    batch_size      = 32,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - loss: 29.5723 - mae: 4.2101 - rmse: 5.4324 - val_loss: 76.2407 - val_mae: 8.6109 - val_rmse: 8.7281 - learning_rate: 1.0000e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - loss: 8.4461 - mae: 2.3190 - rmse: 2.8956 - val_loss: 83.2361 - val_mae: 9.0203 - val_rmse: 9.1200 - learning_rate: 1.0000e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - loss: 7.1925 - mae: 2.1123 - rmse: 2.6705 - val_loss: 73.7150 - val_mae: 8.4916 - val_rmse: 8.5822 - learning_rate: 1.0000e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 151s 3s/step - loss: 6.5882 - mae: 2.0334 - rmse: 2.5548 - val_loss: 70.9934 - val_mae: 8.3434 - val_rmse: 8.4221 - learning_rate: 1.0000e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - loss: 5.7957 - mae: 1.9112 - rmse: 2.3948 - val_loss: 66.6944 - val_mae: 8.0841 - val_rmse: 8.1629 - learning_rate: 1.0000e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - loss: 5.7986 - mae: 1.9033 - rmse: 2.3954 - val_loss: 52.1991 - val_mae: 7.1382 - val_rmse: 7.2207 - learning_rate: 1.0000e-04
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - loss: 5.2074 - mae: 1.8094 - rmse: 2.2687 - val_loss: 41.7476 - val_mae: 6.3762 - val_rmse: 6.4566 - learning_rate: 1.0000e-04
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - loss: 4.9119 - mae: 1.7441 - rmse: 2.2026 - val_loss: 27.5699 - val_mae: 5.1436 - val_rmse: 5.2450 - learning_rate: 1.0000e-04
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 150s 3s/step - loss: 4.8714 - mae: 1.7560 - rmse: 2.1934 - val_loss: 15.8209 - val_mae: 3.8431 - val_rmse: 3.9700 - learning_rate: 1.0000e-04
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 226s 4s/step - loss: 4.8896 - mae: 1.7498 - rmse: 2.1976 - val_loss: 7.7933 - val_mae: 2.5882 - val_rmse: 2.7808 - learning_rate: 1.0000e-04
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 169s 3s/step - loss: 4.5182 - mae: 1.6732 - rmse: 2.1114 - val_loss: 2.4972 - val_mae: 1.2617 - val_rmse: 1.5611 - learning_rate: 1.0000e-04
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - loss: 4.3630 - mae: 1.6546 - rmse: 2.0744 - val_loss: 2.9679 - val_mae: 1.4348 - val_rmse: 1.7052 - learning_rate: 1.0000e-04
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 151s 3s/step - loss: 4.1565 - mae: 1.6280 - rmse: 2.0240 - val_loss: 1.1610 - val_mae: 0.8441 - val_rmse: 1.0493 - learning_rate: 1.0000e-04
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 4.5124 - mae: 1.6901 - rmse: 2.1101 - val_loss: 1.8281 - val_mae: 1.0228 - val_rmse: 1.3297 - learning_rate: 1.0000e-04
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - loss: 4.1853 - mae: 1.6135 - rmse: 2.0311 - val_loss: 2.0353 - val_mae: 1.1027 - val_rmse: 1.4055 - learning_rate: 1.0000e-04
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 3.9766 - mae: 1.5899 - rmse: 1.9791 - val_loss: 2.6062 - val_mae: 1.3068 - val_rmse: 1.5957 - learning_rate: 1.0000e-04
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 141s 2s/step - loss: 4.1340 - mae: 1.6011 - rmse: 2.0185 - val_loss: 7.2543 - val_mae: 2.4855 - val_rmse: 2.6823 - learning_rate: 1.0000e-04
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - loss: 4.0557 - mae: 1.5910 - rmse: 1.9990 - val_loss: 1.2574 - val_mae: 0.8480 - val_rmse: 1.0944 - learning_rate: 1.0000e-04
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - loss: 3.9082 - mae: 1.5699 - rmse: 1.9618 - val_loss: 1.3011 - val_mae: 0.8763 - val_rmse: 1.1142 - learning_rate: 5.0000e-05
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 3.3918 - mae: 1.4550 - rmse: 1.8254 - val_loss: 1.5338 - val_mae: 0.9341 - val_rmse: 1.2141 - learning_rate: 5.0000e-05
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 211s 4s/step - loss: 3.4852 - mae: 1.4851 - rmse: 1.8508 - val_loss: 3.0749 - val_mae: 1.4208 - val_rmse: 1.7364 - learning_rate: 5.0000e-05
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 3.7482 - mae: 1.5249 - rmse: 1.9206 - val_loss: 1.9841 - val_mae: 1.0798 - val_rmse: 1.3873 - learning_rate: 5.0000e-05
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 179s 3s/step - loss: 3.6132 - mae: 1.4902 - rmse: 1.8851 - val_loss: 1.6576 - val_mae: 0.9846 - val_rmse: 1.2641 - learning_rate: 5.0000e-05
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
evaluate_regression_model("CNN", model_1_REG, history_1_REG)
# Out:
# CNN
# Metric                 Validation       Test
# Loss (MSE)                 1.1610     1.0272
# MAE                        0.8441     0.8195
# RMSE                       1.0493     0.9835
# R²                                    0.4736

# %%
model_2_REG = build_models(backbone="cnn2",mode="regression")

# %%
model_2_REG.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss      = "mse",
    metrics   = [
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.RootMeanSquaredError(name="rmse")
    ]
)

history_2_REG = model_2_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train,       
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val),  # ← y_hb_val
    epochs          = 100,
    batch_size      = 32,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - loss: 51.5746 - mae: 6.0520 - rmse: 7.1779 - val_loss: 135.6458 - val_mae: 11.5545 - val_rmse: 11.6444 - learning_rate: 1.0000e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 170s 3s/step - loss: 8.3388 - mae: 2.3179 - rmse: 2.8786 - val_loss: 141.8030 - val_mae: 11.8096 - val_rmse: 11.9059 - learning_rate: 1.0000e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - loss: 7.2649 - mae: 2.1494 - rmse: 2.6856 - val_loss: 134.8977 - val_mae: 11.5164 - val_rmse: 11.6123 - learning_rate: 1.0000e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 167s 3s/step - loss: 6.1151 - mae: 1.9691 - rmse: 2.4623 - val_loss: 127.3848 - val_mae: 11.1940 - val_rmse: 11.2842 - learning_rate: 1.0000e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 165s 3s/step - loss: 5.9155 - mae: 1.9251 - rmse: 2.4214 - val_loss: 114.8209 - val_mae: 10.6258 - val_rmse: 10.7130 - learning_rate: 1.0000e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 165s 3s/step - loss: 5.7797 - mae: 1.9150 - rmse: 2.3932 - val_loss: 103.9984 - val_mae: 10.1082 - val_rmse: 10.1954 - learning_rate: 5.0000e-05
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - loss: 5.5111 - mae: 1.8848 - rmse: 2.3365 - val_loss: 95.7266 - val_mae: 9.6916 - val_rmse: 9.7813 - learning_rate: 5.0000e-05
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 207s 3s/step - loss: 5.2696 - mae: 1.8332 - rmse: 2.2842 - val_loss: 85.5374 - val_mae: 9.1548 - val_rmse: 9.2458 - learning_rate: 5.0000e-05
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 5.0010 - mae: 1.7629 - rmse: 2.2246 - val_loss: 77.3925 - val_mae: 8.7022 - val_rmse: 8.7944 - learning_rate: 5.0000e-05
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 262s 5s/step - loss: 5.0930 - mae: 1.7969 - rmse: 2.2453 - val_loss: 69.3912 - val_mae: 8.2300 - val_rmse: 8.3270 - learning_rate: 5.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
evaluate_regression_model("CNN: Version 2", model_2_REG,  history_2_REG)
# Out:
# CNN: Version 2
# Metric                 Validation       Test
# Loss (MSE)               135.6458   131.4568
# MAE                       11.5545    11.3931
# RMSE                      11.6444    11.4632
# R²                                  -70.5114

# %% [markdown]
# ## Mobile Net

# %%
model_3_REG = build_models(backbone="mobilenetv2",mode="regression")

# %%
model_3_REG.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss      = "mse",
    metrics   = [
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.RootMeanSquaredError(name="rmse")
    ]
)

history_3_REG = model_3_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train,       # ← HB values not labels
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val),  # ← y_hb_val
    epochs          = 100,
    batch_size      = 32,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 107s 999ms/step - loss: 6.3032 - mae: 1.9763 - rmse: 2.4985 - val_loss: 7.8284 - val_mae: 2.5301 - val_rmse: 2.7872 - learning_rate: 1.0000e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 42s 731ms/step - loss: 5.6245 - mae: 1.8651 - rmse: 2.3591 - val_loss: 12.8410 - val_mae: 3.3945 - val_rmse: 3.5752 - learning_rate: 1.0000e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 43s 740ms/step - loss: 4.9394 - mae: 1.7723 - rmse: 2.2093 - val_loss: 17.4170 - val_mae: 4.0075 - val_rmse: 4.1664 - learning_rate: 1.0000e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 46s 791ms/step - loss: 4.9734 - mae: 1.7702 - rmse: 2.2171 - val_loss: 19.4559 - val_mae: 4.2786 - val_rmse: 4.4044 - learning_rate: 1.0000e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 42s 721ms/step - loss: 4.4811 - mae: 1.6705 - rmse: 2.1033 - val_loss: 12.3230 - val_mae: 3.3286 - val_rmse: 3.5023 - learning_rate: 1.0000e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 43s 735ms/step - loss: 4.4460 - mae: 1.6825 - rmse: 2.0950 - val_loss: 8.3569 - val_mae: 2.6682 - val_rmse: 2.8810 - learning_rate: 5.0000e-05
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 42s 730ms/step - loss: 4.3030 - mae: 1.6506 - rmse: 2.0607 - val_loss: 9.5236 - val_mae: 2.8880 - val_rmse: 3.0769 - learning_rate: 5.0000e-05
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 43s 741ms/step - loss: 3.8572 - mae: 1.5312 - rmse: 1.9495 - val_loss: 11.8560 - val_mae: 3.2774 - val_rmse: 3.4351 - learning_rate: 5.0000e-05
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 644ms/step - loss: 4.1295 - mae: 1.6041 - rmse: 2.0182 - val_loss: 10.0550 - val_mae: 2.9869 - val_rmse: 3.1621 - learning_rate: 5.0000e-05
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 42s 717ms/step - loss: 3.8346 - mae: 1.5362 - rmse: 1.9439 - val_loss: 8.2311 - val_mae: 2.6606 - val_rmse: 2.8592 - learning_rate: 5.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
evaluate_regression_model("MobileNet", model_3_REG,  history_3_REG)
# Out:
# MobileNet
# Metric                 Validation       Test
# Loss (MSE)                 7.8284     6.1649
# MAE                        2.5301     2.2754
# RMSE                       2.7872     2.4709
# R²                                   -2.3225

# %% [markdown]
# ## Efficient NetB0

# %%
model_4_REG = build_models(backbone="efficientnetb0",mode="regression")

# %%
model_4_REG.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4) ,
    loss      = "mse",
    metrics   = [
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.RootMeanSquaredError(name="rmse")
    ]
)

# %%
history_4_REG = model_4_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train,       # ← HB values not labels
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val),  # ← y_hb_val
    epochs          = 100,
    batch_size      = 32,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - loss: 69.7836 - mae: 7.2243 - rmse: 8.3500 - val_loss: 4.2288 - val_mae: 1.5170 - val_rmse: 2.0413 - learning_rate: 1.0000e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - loss: 11.4050 - mae: 2.6972 - rmse: 3.3680 - val_loss: 3.7390 - val_mae: 1.4391 - val_rmse: 1.9177 - learning_rate: 1.0000e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - loss: 9.6396 - mae: 2.4894 - rmse: 3.0948 - val_loss: 2.8888 - val_mae: 1.2679 - val_rmse: 1.6815 - learning_rate: 1.0000e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - loss: 8.0950 - mae: 2.2765 - rmse: 2.8343 - val_loss: 2.2353 - val_mae: 1.1265 - val_rmse: 1.4744 - learning_rate: 1.0000e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 7.3291 - mae: 2.1509 - rmse: 2.6959 - val_loss: 1.5571 - val_mae: 0.9575 - val_rmse: 1.2230 - learning_rate: 1.0000e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 7.0865 - mae: 2.1067 - rmse: 2.6505 - val_loss: 1.2626 - val_mae: 0.8789 - val_rmse: 1.0961 - learning_rate: 5.0000e-05
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 6.5353 - mae: 2.0345 - rmse: 2.5444 - val_loss: 1.2217 - val_mae: 0.8610 - val_rmse: 1.0773 - learning_rate: 5.0000e-05
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - loss: 6.1492 - mae: 1.9674 - rmse: 2.4674 - val_loss: 0.9975 - val_mae: 0.7858 - val_rmse: 0.9677 - learning_rate: 5.0000e-05
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 5.8841 - mae: 1.9224 - rmse: 2.4131 - val_loss: 1.1553 - val_mae: 0.8249 - val_rmse: 1.0460 - learning_rate: 5.0000e-05
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 6.0319 - mae: 1.9325 - rmse: 2.4435 - val_loss: 1.0176 - val_mae: 0.7794 - val_rmse: 0.9780 - learning_rate: 5.0000e-05
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - loss: 5.8648 - mae: 1.9053 - rmse: 2.4091 - val_loss: 1.0824 - val_mae: 0.7943 - val_rmse: 1.0106 - learning_rate: 5.0000e-05
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 5.9102 - mae: 1.9348 - rmse: 2.4185 - val_loss: 1.8808 - val_mae: 1.0885 - val_rmse: 1.3490 - learning_rate: 5.0000e-05
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - loss: 5.5324 - mae: 1.8722 - rmse: 2.3391 - val_loss: 1.1268 - val_mae: 0.8000 - val_rmse: 1.0324 - learning_rate: 5.0000e-05
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 5.8239 - mae: 1.9059 - rmse: 2.4006 - val_loss: 1.2128 - val_mae: 0.8362 - val_rmse: 1.0733 - learning_rate: 5.0000e-05
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - loss: 5.4323 - mae: 1.8381 - rmse: 2.3176 - val_loss: 1.6339 - val_mae: 1.0037 - val_rmse: 1.2542 - learning_rate: 5.0000e-05
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - loss: 5.5117 - mae: 1.8690 - rmse: 2.3347 - val_loss: 1.2749 - val_mae: 0.8629 - val_rmse: 1.1018 - learning_rate: 2.5000e-05
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - loss: 5.5369 - mae: 1.8661 - rmse: 2.3401 - val_loss: 1.6693 - val_mae: 1.0141 - val_rmse: 1.2683 - learning_rate: 2.5000e-05
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - loss: 5.2939 - mae: 1.8187 - rmse: 2.2876 - val_loss: 1.2941 - val_mae: 0.8707 - val_rmse: 1.1105 - learning_rate: 2.5000e-05
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - loss: 5.3712 - mae: 1.8234 - rmse: 2.3044 - val_loss: 1.4540 - val_mae: 0.9308 - val_rmse: 1.1804 - learning_rate: 2.5000e-05
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 101s 2s/step - loss: 5.4251 - mae: 1.8648 - rmse: 2.3161 - val_loss: 1.5646 - val_mae: 0.9695 - val_rmse: 1.2263 - learning_rate: 2.5000e-05
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
evaluate_regression_model("EfficientNetB0", model_4_REG,  history_4_REG)
# Out:
# EfficientNetB0
# Metric                 Validation       Test
# Loss (MSE)                 1.0176     0.9354
# MAE                        0.7794     0.7777
# RMSE                       0.9780     0.9350
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000238931BA0C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# R²                                    0.5242

# %% [markdown]
# ## DenseNet121

# %%
model_5_REG = build_models(backbone="densenet121",mode="regression")

# %%
model_5_REG.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss      = "mse",
    metrics   = [
        tf.keras.metrics.MeanAbsoluteError(name="mae"),
        tf.keras.metrics.RootMeanSquaredError(name="rmse")
    ]
)

history_5_REG = model_5_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train,       # ← HB values not labels
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val),  # ← y_hb_val
    epochs          = 100,
    batch_size      = 32,
    callbacks       = callbacks,
    verbose         = 1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 366s 5s/step - loss: 43.6324 - mae: 5.3286 - rmse: 6.6008 - val_loss: 15.6496 - val_mae: 3.5980 - val_rmse: 3.9481 - learning_rate: 1.0000e-04
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 243s 4s/step - loss: 9.2664 - mae: 2.4180 - rmse: 3.0339 - val_loss: 3.5456 - val_mae: 1.4462 - val_rmse: 1.8665 - learning_rate: 1.0000e-04
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 243s 4s/step - loss: 7.5391 - mae: 2.1785 - rmse: 2.7345 - val_loss: 2.1187 - val_mae: 1.1064 - val_rmse: 1.4343 - learning_rate: 1.0000e-04
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 241s 4s/step - loss: 6.7527 - mae: 2.0798 - rmse: 2.5867 - val_loss: 1.9428 - val_mae: 1.0759 - val_rmse: 1.3716 - learning_rate: 1.0000e-04
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 215s 4s/step - loss: 6.1305 - mae: 1.9762 - rmse: 2.4635 - val_loss: 1.3430 - val_mae: 0.8953 - val_rmse: 1.1321 - learning_rate: 1.0000e-04
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 244s 4s/step - loss: 5.4311 - mae: 1.8503 - rmse: 2.3173 - val_loss: 1.7504 - val_mae: 1.0002 - val_rmse: 1.2996 - learning_rate: 5.0000e-05
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 232s 4s/step - loss: 5.3627 - mae: 1.8338 - rmse: 2.3025 - val_loss: 1.8080 - val_mae: 1.0273 - val_rmse: 1.3216 - learning_rate: 5.0000e-05
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 232s 4s/step - loss: 5.1848 - mae: 1.8007 - rmse: 2.2635 - val_loss: 1.7012 - val_mae: 0.9876 - val_rmse: 1.2806 - learning_rate: 5.0000e-05
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 238s 4s/step - loss: 4.8840 - mae: 1.7624 - rmse: 2.1961 - val_loss: 1.5675 - val_mae: 0.9452 - val_rmse: 1.2273 - learning_rate: 5.0000e-05
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - loss: 5.0263 - mae: 1.7683 - rmse: 2.2282 - val_loss: 1.9096 - val_mae: 1.0610 - val_rmse: 1.3596 - learning_rate: 5.0000e-05
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
evaluate_regression_model("DenseNet", model_5_REG,  history_5_REG)
# Out:
# DenseNet
# Metric                 Validation       Test
# Loss (MSE)                15.6496    12.9424
# MAE                        3.5980     3.3110
# RMSE                       3.9481     3.5890
# WARNING:tensorflow:6 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002389AE07560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# R²                                   -6.0097

# %% [markdown]
# # Comparision Table

# %%
# ── Final Regression Comparison Table ───────────────────────────
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

all_models = [
    ("CNN1",           model_1_REG),
    ("CNN2",           model_2_REG),
    ("MobileNetV2",    model_3_REG),
    ("EfficientNetB0", model_4_REG),
    ("DenseNet121",    model_5_REG),
]

results = []
for name, model in all_models:
    y_hb_pred_val  = model.predict([X_palm_val,  X_nail_val,  X_meta_val],  verbose=0).ravel()
    y_hb_pred_test = model.predict([X_palm_test, X_nail_test, X_meta_test], verbose=0).ravel()

    results.append({
        "Model"    : name,
        "Val MAE"  : round(mean_absolute_error(y_hb_val,  y_hb_pred_val),  4),
        "Test MAE" : round(mean_absolute_error(y_hb_test, y_hb_pred_test), 4),
        "Test RMSE": round(np.sqrt(mean_squared_error(y_hb_test, y_hb_pred_test)), 4),
        "Test R²"  : round(r2_score(y_hb_test, y_hb_pred_test), 4),
    })

df = pd.DataFrame(results).sort_values("Val MAE", ascending=True).reset_index(drop=True)
df.index += 1

print(f"\n{'='*65}")
print(f"  FINAL REGRESSION MODEL COMPARISON")
print(f"{'='*65}")
print(df.to_string())
print(f"\n✅ Best Backbone (by Val MAE): {df.iloc[0]['Model']} (Val MAE = {df.iloc[0]['Val MAE']}, Test MAE = {df.iloc[0]['Test MAE']})")
# Out:
# =================================================================
#   FINAL REGRESSION MODEL COMPARISON
# =================================================================
#             Model  Val MAE  Test MAE  Test RMSE  Test R²
# 1  EfficientNetB0   0.7794    0.7777     0.9350   0.5242
# 2            CNN1   0.8336    0.7576     0.9599   0.4986
# 3     MobileNetV2   2.5301    2.2754     2.4709  -2.3225
# 4     DenseNet121   3.5980    3.3110     3.5890  -6.0097
# 5            CNN2  11.5545   11.3931    11.4632 -70.5114
#
# ✅ Best Backbone (by Val MAE): EfficientNetB0 (Val MAE = 0.7794, Test MAE = 0.7777)

# %%
model_4_REG.save("Regression_Models/EfficientNetB0_Regression.keras")
model_1_REG.save("Regression_Models/CNN1_Regression.keras")

# %% [markdown]
# # KFOLD WITH the best one

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

N_SPLITS            = 5
skf                 = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
train_subject_ids   = subject_ids[train_idx]
unique_train_subj   = np.unique(train_subject_ids)
unique_train_labels = np.array([y_label[train_idx][train_subject_ids == s][0]
                                 for s in unique_train_subj])
fold_results = []

# %%
for fold, (tr_subj_idx, vl_subj_idx) in enumerate(
    skf.split(unique_train_subj, unique_train_labels)
):
    print(f"\n{'='*50}")
    print(f"FOLD {fold+1}/{N_SPLITS}")
    print(f"{'='*50}")

    tr_subj = unique_train_subj[tr_subj_idx]
    vl_subj = unique_train_subj[vl_subj_idx]
    tr_idx  = np.where(np.isin(train_subject_ids, tr_subj))[0]
    vl_idx  = np.where(np.isin(train_subject_ids, vl_subj))[0]

    X_palm_tr = X_palm_train[tr_idx];  X_palm_vl = X_palm_train[vl_idx]
    X_nail_tr = X_nail_train[tr_idx];  X_nail_vl = X_nail_train[vl_idx]
    X_meta_tr = X_meta_train[tr_idx];  X_meta_vl = X_meta_train[vl_idx]
    y_hb_tr   = y_hb_train[tr_idx];    y_hb_vl   = y_hb_train[vl_idx]

    # ── Augment fold training data ───────────────────────────────
    X_palm_tr, X_nail_tr, X_meta_tr, y_hb_tr = augment_training_set(
        X_palm_tr, X_nail_tr, X_meta_tr, y_hb_tr
    )
    print(f"Train size : {len(y_hb_tr)} | Val size: {len(y_hb_vl)}")
    print(f"HB range   : {y_hb_tr.min():.1f} — {y_hb_tr.max():.1f} g/dL")

    # ── Model ────────────────────────────────────────────────────
    model_6_REG = build_models(backbone="efficientnetb0", mode="regression")
    model_6_REG.compile(
        optimizer = tf.keras.optimizers.Adam(learning_rate=1e-6) ,
        loss      = "mse",
        metrics   = [
            tf.keras.metrics.MeanAbsoluteError(name="mae"),
            tf.keras.metrics.RootMeanSquaredError(name="rmse")
        ]
    )

    fold_callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_mae", patience=10,
            mode="min", restore_best_weights=True, verbose=0
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_mae", patience=5,
            mode="min", factor=0.5, min_lr=1e-6, verbose=0
        )
    ]

    history_6_REG =  model_6_REG.fit(
        x               = [X_palm_tr, X_nail_tr, X_meta_tr],
        y               = y_hb_tr,
        validation_data = ([X_palm_vl, X_nail_vl, X_meta_vl], y_hb_vl),
        epochs=100, batch_size=32,
        callbacks=fold_callbacks, verbose=1
    )

    # ── Evaluate fold ────────────────────────────────────────────
    y_hb_pred =  model_6_REG.predict([X_palm_vl, X_nail_vl, X_meta_vl], verbose=0).ravel()
    mae       = mean_absolute_error(y_hb_vl,  y_hb_pred)
    rmse      = np.sqrt(mean_squared_error(y_hb_vl, y_hb_pred))
    r2        = r2_score(y_hb_vl, y_hb_pred)

    print(f"\nFold {fold+1} → MAE: {mae:.4f} | RMSE: {rmse:.4f} | R²: {r2:.4f}")

    fold_results.append({
        "fold"   : fold + 1,
        "mae"    : mae,
        "rmse"   : rmse,
        "r2"     : r2,
        "model"  : model_6_REG,
        "history": history_6_REG
    })
# Out:
# ==================================================
# FOLD 1/5
# ==================================================
# Train size : 1470 | Val size: 74
# HB range   : 8.9 — 17.0 g/dL
# WARNING:tensorflow:From c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - loss: 113.1240 - mae: 10.4414 - rmse: 10.6331 - val_loss: 80.9813 - val_mae: 8.8581 - val_rmse: 8.9955 - learning_rate: 1.0000e-05
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - loss: 53.6051 - mae: 6.8765 - rmse: 7.3173 - val_loss: 24.3791 - val_mae: 4.6710 - val_rmse: 4.9313 - learning_rate: 1.0000e-05
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - loss: 21.1464 - mae: 3.8551 - rmse: 4.5918 - val_loss: 4.7141 - val_mae: 1.6295 - val_rmse: 2.1569 - learning_rate: 1.0000e-05
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 13.0721 - mae: 2.8998 - rmse: 3.6070 - val_loss: 2.4600 - val_mae: 1.2474 - val_rmse: 1.5486 - learning_rate: 1.0000e-05
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 192s 3s/step - loss: 12.1461 - mae: 2.8147 - rmse: 3.4763 - val_loss: 2.4775 - val_mae: 1.2932 - val_rmse: 1.5543 - learning_rate: 1.0000e-05
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 10.2159 - mae: 2.5799 - rmse: 3.1866 - val_loss: 2.4670 - val_mae: 1.2957 - val_rmse: 1.5509 - learning_rate: 1.0000e-05
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - loss: 10.6655 - mae: 2.6068 - rmse: 3.2564 - val_loss: 2.2105 - val_mae: 1.2248 - val_rmse: 1.4659 - learning_rate: 1.0000e-05
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - loss: 10.7963 - mae: 2.6311 - rmse: 3.2764 - val_loss: 1.9796 - val_mae: 1.1453 - val_rmse: 1.3849 - learning_rate: 1.0000e-05
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - loss: 10.1802 - mae: 2.5433 - rmse: 3.1810 - val_loss: 1.7997 - val_mae: 1.0754 - val_rmse: 1.3183 - learning_rate: 1.0000e-05
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - loss: 9.3080 - mae: 2.4015 - rmse: 3.0408 - val_loss: 1.6648 - val_mae: 1.0238 - val_rmse: 1.2661 - learning_rate: 1.0000e-05
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 9.4588 - mae: 2.4796 - rmse: 3.0655 - val_loss: 1.5902 - val_mae: 1.0004 - val_rmse: 1.2363 - learning_rate: 1.0000e-05
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 9.5195 - mae: 2.4405 - rmse: 3.0754 - val_loss: 1.5062 - val_mae: 0.9711 - val_rmse: 1.2019 - learning_rate: 1.0000e-05
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - loss: 8.8286 - mae: 2.3448 - rmse: 2.9609 - val_loss: 1.3884 - val_mae: 0.9291 - val_rmse: 1.1519 - learning_rate: 1.0000e-05
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - loss: 8.7276 - mae: 2.3374 - rmse: 2.9438 - val_loss: 1.3183 - val_mae: 0.9104 - val_rmse: 1.1210 - learning_rate: 1.0000e-05
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - loss: 8.9073 - mae: 2.3735 - rmse: 2.9742 - val_loss: 1.2846 - val_mae: 0.9039 - val_rmse: 1.1059 - learning_rate: 1.0000e-05
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - loss: 8.0503 - mae: 2.2455 - rmse: 2.8264 - val_loss: 1.2046 - val_mae: 0.8799 - val_rmse: 1.0691 - learning_rate: 1.0000e-05
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 8.3720 - mae: 2.3001 - rmse: 2.8828 - val_loss: 1.1525 - val_mae: 0.8618 - val_rmse: 1.0444 - learning_rate: 1.0000e-05
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - loss: 7.7094 - mae: 2.2111 - rmse: 2.7655 - val_loss: 1.1729 - val_mae: 0.8800 - val_rmse: 1.0542 - learning_rate: 1.0000e-05
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 7.4347 - mae: 2.1714 - rmse: 2.7153 - val_loss: 1.2195 - val_mae: 0.9004 - val_rmse: 1.0761 - learning_rate: 1.0000e-05
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - loss: 7.6713 - mae: 2.2054 - rmse: 2.7586 - val_loss: 1.1805 - val_mae: 0.8845 - val_rmse: 1.0578 - learning_rate: 1.0000e-05
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - loss: 7.1410 - mae: 2.1462 - rmse: 2.6607 - val_loss: 1.2032 - val_mae: 0.8910 - val_rmse: 1.0685 - learning_rate: 1.0000e-05
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - loss: 7.2152 - mae: 2.1351 - rmse: 2.6746 - val_loss: 1.1294 - val_mae: 0.8603 - val_rmse: 1.0334 - learning_rate: 1.0000e-05
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 7.5936 - mae: 2.1590 - rmse: 2.7445 - val_loss: 1.1077 - val_mae: 0.8456 - val_rmse: 1.0228 - learning_rate: 1.0000e-05
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - loss: 7.1090 - mae: 2.1324 - rmse: 2.6547 - val_loss: 1.2340 - val_mae: 0.8923 - val_rmse: 1.0828 - learning_rate: 1.0000e-05
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 6.7909 - mae: 2.0779 - rmse: 2.5941 - val_loss: 1.2425 - val_mae: 0.8949 - val_rmse: 1.0867 - learning_rate: 1.0000e-05
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - loss: 6.5124 - mae: 2.0076 - rmse: 2.5399 - val_loss: 1.3162 - val_mae: 0.9200 - val_rmse: 1.1201 - learning_rate: 1.0000e-05
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - loss: 7.0902 - mae: 2.1369 - rmse: 2.6512 - val_loss: 1.0551 - val_mae: 0.8249 - val_rmse: 0.9968 - learning_rate: 1.0000e-05
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 6.9861 - mae: 2.1308 - rmse: 2.6315 - val_loss: 1.3133 - val_mae: 0.9211 - val_rmse: 1.1189 - learning_rate: 1.0000e-05
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 6.8945 - mae: 2.0784 - rmse: 2.6140 - val_loss: 1.6312 - val_mae: 1.0395 - val_rmse: 1.2529 - learning_rate: 1.0000e-05
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step - loss: 6.6187 - mae: 2.0386 - rmse: 2.5607 - val_loss: 1.1596 - val_mae: 0.8604 - val_rmse: 1.0479 - learning_rate: 1.0000e-05
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - loss: 6.7300 - mae: 2.0564 - rmse: 2.5823 - val_loss: 1.4100 - val_mae: 0.9567 - val_rmse: 1.1612 - learning_rate: 1.0000e-05
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - loss: 6.3098 - mae: 2.0144 - rmse: 2.4997 - val_loss: 1.2905 - val_mae: 0.9081 - val_rmse: 1.1086 - learning_rate: 1.0000e-05
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - loss: 5.9294 - mae: 1.9547 - rmse: 2.4224 - val_loss: 1.4022 - val_mae: 0.9513 - val_rmse: 1.1579 - learning_rate: 5.0000e-06
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 93s 2s/step - loss: 6.4005 - mae: 2.0073 - rmse: 2.5177 - val_loss: 1.3574 - val_mae: 0.9316 - val_rmse: 1.1384 - learning_rate: 5.0000e-06
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 157s 3s/step - loss: 6.4782 - mae: 2.0177 - rmse: 2.5331 - val_loss: 1.2276 - val_mae: 0.8808 - val_rmse: 1.0799 - learning_rate: 5.0000e-06
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 279s 5s/step - loss: 6.2594 - mae: 1.9702 - rmse: 2.4896 - val_loss: 1.2595 - val_mae: 0.8911 - val_rmse: 1.0945 - learning_rate: 5.0000e-06
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - loss: 5.8966 - mae: 1.9385 - rmse: 2.4156 - val_loss: 1.3022 - val_mae: 0.9071 - val_rmse: 1.1139 - learning_rate: 5.0000e-06
#
# Fold 1 → MAE: 0.8249 | RMSE: 0.9968 | R²: 0.4445
#
# ==================================================
# FOLD 2/5
# ==================================================
# Train size : 1470 | Val size: 74
# HB range   : 8.9 — 17.0 g/dL
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 114s 2s/step - loss: 134.1071 - mae: 11.4339 - rmse: 11.5778 - val_loss: 106.1802 - val_mae: 10.2281 - val_rmse: 10.3014 - learning_rate: 1.0000e-05
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - loss: 85.4841 - mae: 9.0227 - rmse: 9.2424 - val_loss: 61.0291 - val_mae: 7.7103 - val_rmse: 7.8081 - learning_rate: 1.0000e-05
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - loss: 50.6976 - mae: 6.7022 - rmse: 7.1159 - val_loss: 28.8533 - val_mae: 5.2120 - val_rmse: 5.3658 - learning_rate: 1.0000e-05
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 29.2535 - mae: 4.7335 - rmse: 5.4029 - val_loss: 10.6889 - val_mae: 2.9792 - val_rmse: 3.2599 - learning_rate: 1.0000e-05
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 18.0328 - mae: 3.5270 - rmse: 4.2392 - val_loss: 3.8513 - val_mae: 1.4879 - val_rmse: 1.9466 - learning_rate: 1.0000e-05
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 13.3525 - mae: 2.9441 - rmse: 3.6456 - val_loss: 1.9646 - val_mae: 1.0173 - val_rmse: 1.3794 - learning_rate: 1.0000e-05
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 12.7563 - mae: 2.8642 - rmse: 3.5629 - val_loss: 1.7511 - val_mae: 1.0434 - val_rmse: 1.2997 - learning_rate: 1.0000e-05
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - loss: 11.8734 - mae: 2.7264 - rmse: 3.4368 - val_loss: 1.7428 - val_mae: 1.0748 - val_rmse: 1.2965 - learning_rate: 1.0000e-05
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 10.6289 - mae: 2.6080 - rmse: 3.2507 - val_loss: 1.6675 - val_mae: 1.0480 - val_rmse: 1.2671 - learning_rate: 1.0000e-05
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 10.5195 - mae: 2.5776 - rmse: 3.2338 - val_loss: 1.5550 - val_mae: 0.9927 - val_rmse: 1.2219 - learning_rate: 1.0000e-05
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 10.0914 - mae: 2.5311 - rmse: 3.1669 - val_loss: 1.5030 - val_mae: 0.9775 - val_rmse: 1.2005 - learning_rate: 1.0000e-05
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 10.1846 - mae: 2.5458 - rmse: 3.1816 - val_loss: 1.4614 - val_mae: 0.9777 - val_rmse: 1.1830 - learning_rate: 1.0000e-05
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 10.6199 - mae: 2.5692 - rmse: 3.2493 - val_loss: 1.3446 - val_mae: 0.9209 - val_rmse: 1.1326 - learning_rate: 1.0000e-05
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 10.3799 - mae: 2.5703 - rmse: 3.2122 - val_loss: 1.2531 - val_mae: 0.8652 - val_rmse: 1.0914 - learning_rate: 1.0000e-05
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 10.4060 - mae: 2.6062 - rmse: 3.2162 - val_loss: 1.2044 - val_mae: 0.8538 - val_rmse: 1.0689 - learning_rate: 1.0000e-05
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 9.9302 - mae: 2.4845 - rmse: 3.1414 - val_loss: 1.1637 - val_mae: 0.8483 - val_rmse: 1.0497 - learning_rate: 1.0000e-05
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 9.6767 - mae: 2.4818 - rmse: 3.1008 - val_loss: 1.1260 - val_mae: 0.8275 - val_rmse: 1.0316 - learning_rate: 1.0000e-05
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 8.5702 - mae: 2.3362 - rmse: 2.9169 - val_loss: 1.1132 - val_mae: 0.8471 - val_rmse: 1.0254 - learning_rate: 1.0000e-05
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 9.0428 - mae: 2.4216 - rmse: 2.9968 - val_loss: 1.0505 - val_mae: 0.8098 - val_rmse: 0.9943 - learning_rate: 1.0000e-05
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 8.7326 - mae: 2.3693 - rmse: 2.9446 - val_loss: 1.0166 - val_mae: 0.8010 - val_rmse: 0.9771 - learning_rate: 1.0000e-05
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 8.3583 - mae: 2.2994 - rmse: 2.8804 - val_loss: 0.9956 - val_mae: 0.7965 - val_rmse: 0.9663 - learning_rate: 1.0000e-05
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 8.2328 - mae: 2.2767 - rmse: 2.8585 - val_loss: 0.9652 - val_mae: 0.7798 - val_rmse: 0.9505 - learning_rate: 1.0000e-05
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 8.0542 - mae: 2.2614 - rmse: 2.8271 - val_loss: 0.9370 - val_mae: 0.7740 - val_rmse: 0.9355 - learning_rate: 1.0000e-05
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 8.1660 - mae: 2.2883 - rmse: 2.8468 - val_loss: 0.9296 - val_mae: 0.7728 - val_rmse: 0.9316 - learning_rate: 1.0000e-05
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 8.2205 - mae: 2.3140 - rmse: 2.8563 - val_loss: 0.8887 - val_mae: 0.7506 - val_rmse: 0.9093 - learning_rate: 1.0000e-05
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 7.3762 - mae: 2.1726 - rmse: 2.7045 - val_loss: 0.9286 - val_mae: 0.7715 - val_rmse: 0.9310 - learning_rate: 1.0000e-05
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 7.8205 - mae: 2.2542 - rmse: 2.7855 - val_loss: 0.8609 - val_mae: 0.7409 - val_rmse: 0.8940 - learning_rate: 1.0000e-05
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 7.3573 - mae: 2.1508 - rmse: 2.7010 - val_loss: 0.8992 - val_mae: 0.7574 - val_rmse: 0.9151 - learning_rate: 1.0000e-05
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 7.1530 - mae: 2.1409 - rmse: 2.6629 - val_loss: 0.8527 - val_mae: 0.7372 - val_rmse: 0.8893 - learning_rate: 1.0000e-05
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 7.1286 - mae: 2.1374 - rmse: 2.6584 - val_loss: 0.8647 - val_mae: 0.7409 - val_rmse: 0.8961 - learning_rate: 1.0000e-05
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - loss: 7.2740 - mae: 2.1604 - rmse: 2.6856 - val_loss: 0.8378 - val_mae: 0.7302 - val_rmse: 0.8810 - learning_rate: 1.0000e-05
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - loss: 7.1099 - mae: 2.1171 - rmse: 2.6548 - val_loss: 0.8328 - val_mae: 0.7251 - val_rmse: 0.8781 - learning_rate: 1.0000e-05
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - loss: 7.2019 - mae: 2.1352 - rmse: 2.6721 - val_loss: 0.7936 - val_mae: 0.7044 - val_rmse: 0.8555 - learning_rate: 1.0000e-05
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - loss: 6.8591 - mae: 2.0795 - rmse: 2.6072 - val_loss: 0.8349 - val_mae: 0.7211 - val_rmse: 0.8793 - learning_rate: 1.0000e-05
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.9478 - mae: 2.0768 - rmse: 2.6241 - val_loss: 0.8456 - val_mae: 0.7222 - val_rmse: 0.8854 - learning_rate: 1.0000e-05
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.9607 - mae: 2.0781 - rmse: 2.6266 - val_loss: 0.8676 - val_mae: 0.7310 - val_rmse: 0.8977 - learning_rate: 1.0000e-05
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.6414 - mae: 2.0436 - rmse: 2.5651 - val_loss: 0.7643 - val_mae: 0.6830 - val_rmse: 0.8382 - learning_rate: 1.0000e-05
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 6.2434 - mae: 1.9883 - rmse: 2.4863 - val_loss: 0.8522 - val_mae: 0.7203 - val_rmse: 0.8891 - learning_rate: 1.0000e-05
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 6.0627 - mae: 1.9799 - rmse: 2.4497 - val_loss: 0.7757 - val_mae: 0.6858 - val_rmse: 0.8450 - learning_rate: 1.0000e-05
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 6.7122 - mae: 2.0443 - rmse: 2.5789 - val_loss: 0.8448 - val_mae: 0.7207 - val_rmse: 0.8850 - learning_rate: 1.0000e-05
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 6.2094 - mae: 1.9600 - rmse: 2.4795 - val_loss: 0.8194 - val_mae: 0.7070 - val_rmse: 0.8705 - learning_rate: 1.0000e-05
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - loss: 6.3622 - mae: 1.9937 - rmse: 2.5101 - val_loss: 0.9945 - val_mae: 0.7986 - val_rmse: 0.9658 - learning_rate: 1.0000e-05
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.1034 - mae: 1.9617 - rmse: 2.4580 - val_loss: 0.7463 - val_mae: 0.6679 - val_rmse: 0.8274 - learning_rate: 5.0000e-06
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 6.4287 - mae: 1.9853 - rmse: 2.5233 - val_loss: 0.7968 - val_mae: 0.6993 - val_rmse: 0.8574 - learning_rate: 5.0000e-06
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - loss: 6.4946 - mae: 2.0348 - rmse: 2.5363 - val_loss: 0.7865 - val_mae: 0.6917 - val_rmse: 0.8514 - learning_rate: 5.0000e-06
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 6.4604 - mae: 2.0118 - rmse: 2.5296 - val_loss: 0.8246 - val_mae: 0.7106 - val_rmse: 0.8735 - learning_rate: 5.0000e-06
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - loss: 6.0297 - mae: 1.9533 - rmse: 2.4430 - val_loss: 0.9137 - val_mae: 0.7578 - val_rmse: 0.9231 - learning_rate: 5.0000e-06
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.2364 - mae: 1.9769 - rmse: 2.4849 - val_loss: 0.8391 - val_mae: 0.7177 - val_rmse: 0.8817 - learning_rate: 5.0000e-06
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - loss: 6.0929 - mae: 1.9371 - rmse: 2.4559 - val_loss: 0.8166 - val_mae: 0.7069 - val_rmse: 0.8689 - learning_rate: 2.5000e-06
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 6.0051 - mae: 1.9331 - rmse: 2.4379 - val_loss: 0.8149 - val_mae: 0.7058 - val_rmse: 0.8679 - learning_rate: 2.5000e-06
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 5.9411 - mae: 1.8841 - rmse: 2.4248 - val_loss: 0.8652 - val_mae: 0.7307 - val_rmse: 0.8964 - learning_rate: 2.5000e-06
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 6.0358 - mae: 1.9429 - rmse: 2.4442 - val_loss: 0.8420 - val_mae: 0.7182 - val_rmse: 0.8834 - learning_rate: 2.5000e-06
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 5.5879 - mae: 1.8696 - rmse: 2.3508 - val_loss: 0.8320 - val_mae: 0.7140 - val_rmse: 0.8777 - learning_rate: 2.5000e-06
#
# Fold 2 → MAE: 0.6679 | RMSE: 0.8274 | R²: 0.5060
#
# ==================================================
# FOLD 3/5
# ==================================================
# Train size : 1470 | Val size: 74
# HB range   : 9.3 — 17.0 g/dL
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - loss: 114.8705 - mae: 10.5551 - rmse: 10.7149 - val_loss: 101.0228 - val_mae: 9.9214 - val_rmse: 10.0479 - learning_rate: 1.0000e-05
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 67.7050 - mae: 7.9337 - rmse: 8.2245 - val_loss: 52.4362 - val_mae: 7.0421 - val_rmse: 7.2370 - learning_rate: 1.0000e-05
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 36.5185 - mae: 5.5162 - rmse: 6.0379 - val_loss: 20.7724 - val_mae: 4.2283 - val_rmse: 4.5509 - learning_rate: 1.0000e-05
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 19.1667 - mae: 3.6628 - rmse: 4.3709 - val_loss: 6.8460 - val_mae: 2.0908 - val_rmse: 2.6046 - learning_rate: 1.0000e-05
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 13.1311 - mae: 2.9267 - rmse: 3.6151 - val_loss: 3.1892 - val_mae: 1.3710 - val_rmse: 1.7684 - learning_rate: 1.0000e-05
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 11.2514 - mae: 2.7165 - rmse: 3.3451 - val_loss: 2.5564 - val_mae: 1.3361 - val_rmse: 1.5794 - learning_rate: 1.0000e-05
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 10.5784 - mae: 2.6019 - rmse: 3.2429 - val_loss: 2.4253 - val_mae: 1.3361 - val_rmse: 1.5373 - learning_rate: 1.0000e-05
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 10.4139 - mae: 2.5714 - rmse: 3.2175 - val_loss: 2.2719 - val_mae: 1.2796 - val_rmse: 1.4866 - learning_rate: 1.0000e-05
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 9.9280 - mae: 2.4812 - rmse: 3.1410 - val_loss: 2.1523 - val_mae: 1.2205 - val_rmse: 1.4458 - learning_rate: 1.0000e-05
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 9.4088 - mae: 2.4307 - rmse: 3.0573 - val_loss: 2.0301 - val_mae: 1.1946 - val_rmse: 1.4029 - learning_rate: 1.0000e-05
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 9.3937 - mae: 2.4422 - rmse: 3.0548 - val_loss: 1.9549 - val_mae: 1.1576 - val_rmse: 1.3759 - learning_rate: 1.0000e-05
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 9.5515 - mae: 2.4808 - rmse: 3.0805 - val_loss: 1.8881 - val_mae: 1.1266 - val_rmse: 1.3514 - learning_rate: 1.0000e-05
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 9.3217 - mae: 2.4372 - rmse: 3.0430 - val_loss: 1.8446 - val_mae: 1.1001 - val_rmse: 1.3352 - learning_rate: 1.0000e-05
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 8.7395 - mae: 2.3644 - rmse: 2.9458 - val_loss: 1.7222 - val_mae: 1.0777 - val_rmse: 1.2885 - learning_rate: 1.0000e-05
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 8.1450 - mae: 2.3036 - rmse: 2.8431 - val_loss: 1.6447 - val_mae: 1.0446 - val_rmse: 1.2581 - learning_rate: 1.0000e-05
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 8.7393 - mae: 2.3623 - rmse: 2.9458 - val_loss: 1.5834 - val_mae: 1.0222 - val_rmse: 1.2335 - learning_rate: 1.0000e-05
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 8.7022 - mae: 2.3669 - rmse: 2.9394 - val_loss: 1.5841 - val_mae: 1.0090 - val_rmse: 1.2338 - learning_rate: 1.0000e-05
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 8.3012 - mae: 2.2751 - rmse: 2.8704 - val_loss: 1.5473 - val_mae: 0.9895 - val_rmse: 1.2188 - learning_rate: 1.0000e-05
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 8.5648 - mae: 2.3510 - rmse: 2.9160 - val_loss: 1.3978 - val_mae: 0.9469 - val_rmse: 1.1559 - learning_rate: 1.0000e-05
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 7.7925 - mae: 2.2575 - rmse: 2.7804 - val_loss: 1.3696 - val_mae: 0.9326 - val_rmse: 1.1436 - learning_rate: 1.0000e-05
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 7.3674 - mae: 2.1474 - rmse: 2.7029 - val_loss: 1.3748 - val_mae: 0.9296 - val_rmse: 1.1458 - learning_rate: 1.0000e-05
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 7.7230 - mae: 2.2316 - rmse: 2.7679 - val_loss: 1.4202 - val_mae: 0.9381 - val_rmse: 1.1655 - learning_rate: 1.0000e-05
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 7.3397 - mae: 2.1517 - rmse: 2.6977 - val_loss: 1.3548 - val_mae: 0.9178 - val_rmse: 1.1371 - learning_rate: 1.0000e-05
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 7.6380 - mae: 2.2237 - rmse: 2.7525 - val_loss: 1.3407 - val_mae: 0.9104 - val_rmse: 1.1309 - learning_rate: 1.0000e-05
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 7.2686 - mae: 2.1444 - rmse: 2.6845 - val_loss: 1.2976 - val_mae: 0.8962 - val_rmse: 1.1117 - learning_rate: 1.0000e-05
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 7.3429 - mae: 2.1565 - rmse: 2.6984 - val_loss: 1.2539 - val_mae: 0.8846 - val_rmse: 1.0919 - learning_rate: 1.0000e-05
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.9318 - mae: 2.0879 - rmse: 2.6211 - val_loss: 1.2587 - val_mae: 0.8797 - val_rmse: 1.0941 - learning_rate: 1.0000e-05
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 7.1891 - mae: 2.1148 - rmse: 2.6697 - val_loss: 1.1115 - val_mae: 0.8546 - val_rmse: 1.0246 - learning_rate: 1.0000e-05
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 7.1133 - mae: 2.1383 - rmse: 2.6555 - val_loss: 1.2920 - val_mae: 0.8875 - val_rmse: 1.1092 - learning_rate: 1.0000e-05
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 6.9205 - mae: 2.1212 - rmse: 2.6189 - val_loss: 1.2947 - val_mae: 0.8867 - val_rmse: 1.1104 - learning_rate: 1.0000e-05
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 6.9068 - mae: 2.0937 - rmse: 2.6163 - val_loss: 1.2909 - val_mae: 0.8800 - val_rmse: 1.1087 - learning_rate: 1.0000e-05
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 6.7105 - mae: 2.0711 - rmse: 2.5785 - val_loss: 1.2330 - val_mae: 0.8576 - val_rmse: 1.0823 - learning_rate: 1.0000e-05
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.3716 - mae: 2.0146 - rmse: 2.5119 - val_loss: 1.1726 - val_mae: 0.8367 - val_rmse: 1.0540 - learning_rate: 1.0000e-05
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 6.6918 - mae: 2.0527 - rmse: 2.5749 - val_loss: 1.2962 - val_mae: 0.8767 - val_rmse: 1.1111 - learning_rate: 1.0000e-05
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 6.5808 - mae: 2.0375 - rmse: 2.5532 - val_loss: 1.1935 - val_mae: 0.8412 - val_rmse: 1.0639 - learning_rate: 1.0000e-05
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.2101 - mae: 1.9789 - rmse: 2.4796 - val_loss: 1.3143 - val_mae: 0.8782 - val_rmse: 1.1192 - learning_rate: 1.0000e-05
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.2193 - mae: 1.9649 - rmse: 2.4814 - val_loss: 1.2788 - val_mae: 0.8704 - val_rmse: 1.1032 - learning_rate: 1.0000e-05
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.4445 - mae: 2.0292 - rmse: 2.5264 - val_loss: 1.0876 - val_mae: 0.8043 - val_rmse: 1.0129 - learning_rate: 1.0000e-05
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 5.9827 - mae: 1.9563 - rmse: 2.4333 - val_loss: 1.1259 - val_mae: 0.8159 - val_rmse: 1.0316 - learning_rate: 1.0000e-05
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 6.4389 - mae: 2.0248 - rmse: 2.5253 - val_loss: 1.2110 - val_mae: 0.8434 - val_rmse: 1.0721 - learning_rate: 1.0000e-05
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.2985 - mae: 2.0036 - rmse: 2.4974 - val_loss: 1.3149 - val_mae: 0.8775 - val_rmse: 1.1195 - learning_rate: 1.0000e-05
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 5.7892 - mae: 1.9222 - rmse: 2.3932 - val_loss: 1.4010 - val_mae: 0.9088 - val_rmse: 1.1573 - learning_rate: 1.0000e-05
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 5.9594 - mae: 1.9440 - rmse: 2.4285 - val_loss: 1.9274 - val_mae: 1.1146 - val_rmse: 1.3659 - learning_rate: 1.0000e-05
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 6.0377 - mae: 1.9620 - rmse: 2.4446 - val_loss: 1.3344 - val_mae: 0.8856 - val_rmse: 1.1282 - learning_rate: 5.0000e-06
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 6.0259 - mae: 1.9560 - rmse: 2.4422 - val_loss: 1.4703 - val_mae: 0.9352 - val_rmse: 1.1869 - learning_rate: 5.0000e-06
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 6.4151 - mae: 2.0260 - rmse: 2.5206 - val_loss: 1.6541 - val_mae: 1.0089 - val_rmse: 1.2619 - learning_rate: 5.0000e-06
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 5.9459 - mae: 1.9419 - rmse: 2.4258 - val_loss: 1.5979 - val_mae: 0.9901 - val_rmse: 1.2395 - learning_rate: 5.0000e-06
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 5.9276 - mae: 1.9261 - rmse: 2.4220 - val_loss: 1.7106 - val_mae: 1.0357 - val_rmse: 1.2841 - learning_rate: 5.0000e-06
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000019AD0C76840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000019AD0C76840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Fold 3 → MAE: 0.8043 | RMSE: 1.0129 | R²: 0.5169
#
# ==================================================
# FOLD 4/5
# ==================================================
# Train size : 1475 | Val size: 73
# HB range   : 8.9 — 17.0 g/dL
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - loss: 116.9422 - mae: 10.6279 - rmse: 10.8111 - val_loss: 99.6643 - val_mae: 9.8601 - val_rmse: 9.9801 - learning_rate: 1.0000e-05
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 55.7747 - mae: 7.0511 - rmse: 7.4641 - val_loss: 34.9571 - val_mae: 5.6973 - val_rmse: 5.9072 - learning_rate: 1.0000e-05
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 24.9680 - mae: 4.2705 - rmse: 4.9906 - val_loss: 8.4961 - val_mae: 2.5277 - val_rmse: 2.9041 - learning_rate: 1.0000e-05
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 13.6024 - mae: 2.9914 - rmse: 3.6797 - val_loss: 2.6762 - val_mae: 1.2942 - val_rmse: 1.6168 - learning_rate: 1.0000e-05
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 11.3658 - mae: 2.6917 - rmse: 3.3621 - val_loss: 2.1676 - val_mae: 1.2213 - val_rmse: 1.4510 - learning_rate: 1.0000e-05
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 10.6379 - mae: 2.6469 - rmse: 3.2521 - val_loss: 2.2828 - val_mae: 1.2510 - val_rmse: 1.4902 - learning_rate: 1.0000e-05
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 10.4634 - mae: 2.5796 - rmse: 3.2251 - val_loss: 2.1137 - val_mae: 1.1960 - val_rmse: 1.4324 - learning_rate: 1.0000e-05
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 10.8860 - mae: 2.6639 - rmse: 3.2900 - val_loss: 1.9707 - val_mae: 1.1465 - val_rmse: 1.3816 - learning_rate: 1.0000e-05
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 9.8307 - mae: 2.5118 - rmse: 3.1255 - val_loss: 1.7626 - val_mae: 1.0743 - val_rmse: 1.3041 - learning_rate: 1.0000e-05
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 9.3005 - mae: 2.4500 - rmse: 3.0395 - val_loss: 1.7609 - val_mae: 1.0659 - val_rmse: 1.3034 - learning_rate: 1.0000e-05
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 9.1653 - mae: 2.3929 - rmse: 3.0172 - val_loss: 1.6090 - val_mae: 1.0103 - val_rmse: 1.2438 - learning_rate: 1.0000e-05
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 9.3425 - mae: 2.4559 - rmse: 3.0464 - val_loss: 1.5683 - val_mae: 0.9880 - val_rmse: 1.2273 - learning_rate: 1.0000e-05
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 8.4062 - mae: 2.3176 - rmse: 2.8886 - val_loss: 1.4644 - val_mae: 0.9476 - val_rmse: 1.1843 - learning_rate: 1.0000e-05
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 8.5892 - mae: 2.3440 - rmse: 2.9201 - val_loss: 1.4004 - val_mae: 0.9164 - val_rmse: 1.1569 - learning_rate: 1.0000e-05
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 8.7024 - mae: 2.3333 - rmse: 2.9395 - val_loss: 1.3552 - val_mae: 0.8963 - val_rmse: 1.1372 - learning_rate: 1.0000e-05
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 8.3702 - mae: 2.2882 - rmse: 2.8824 - val_loss: 1.3239 - val_mae: 0.8859 - val_rmse: 1.1234 - learning_rate: 1.0000e-05
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 7.7961 - mae: 2.2272 - rmse: 2.7810 - val_loss: 1.2861 - val_mae: 0.8650 - val_rmse: 1.1064 - learning_rate: 1.0000e-05
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 8.2114 - mae: 2.2955 - rmse: 2.8547 - val_loss: 1.2849 - val_mae: 0.8580 - val_rmse: 1.1059 - learning_rate: 1.0000e-05
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 7.2909 - mae: 2.1361 - rmse: 2.6887 - val_loss: 1.2697 - val_mae: 0.8425 - val_rmse: 1.0990 - learning_rate: 1.0000e-05
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 7.6816 - mae: 2.2384 - rmse: 2.7604 - val_loss: 1.2477 - val_mae: 0.8338 - val_rmse: 1.0889 - learning_rate: 1.0000e-05
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.8154 - mae: 2.0778 - rmse: 2.5987 - val_loss: 1.2363 - val_mae: 0.8358 - val_rmse: 1.0837 - learning_rate: 1.0000e-05
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.8515 - mae: 2.0850 - rmse: 2.6057 - val_loss: 1.2360 - val_mae: 0.8398 - val_rmse: 1.0836 - learning_rate: 1.0000e-05
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.9243 - mae: 2.1176 - rmse: 2.6196 - val_loss: 1.2301 - val_mae: 0.8361 - val_rmse: 1.0808 - learning_rate: 1.0000e-05
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.9482 - mae: 2.1055 - rmse: 2.6242 - val_loss: 1.2250 - val_mae: 0.8403 - val_rmse: 1.0785 - learning_rate: 1.0000e-05
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.7021 - mae: 2.0630 - rmse: 2.5769 - val_loss: 1.2004 - val_mae: 0.8244 - val_rmse: 1.0670 - learning_rate: 1.0000e-05
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.9801 - mae: 2.0844 - rmse: 2.6303 - val_loss: 1.2245 - val_mae: 0.8463 - val_rmse: 1.0783 - learning_rate: 1.0000e-05
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.5927 - mae: 2.0300 - rmse: 2.5555 - val_loss: 1.1861 - val_mae: 0.8277 - val_rmse: 1.0603 - learning_rate: 1.0000e-05
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.2402 - mae: 1.9613 - rmse: 2.4856 - val_loss: 1.1799 - val_mae: 0.8297 - val_rmse: 1.0574 - learning_rate: 1.0000e-05
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 6.3627 - mae: 1.9744 - rmse: 2.5102 - val_loss: 1.2065 - val_mae: 0.8460 - val_rmse: 1.0699 - learning_rate: 1.0000e-05
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 6.3333 - mae: 1.9929 - rmse: 2.5043 - val_loss: 1.2888 - val_mae: 0.8731 - val_rmse: 1.1077 - learning_rate: 1.0000e-05
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 6.4757 - mae: 2.0236 - rmse: 2.5326 - val_loss: 1.1726 - val_mae: 0.8271 - val_rmse: 1.0540 - learning_rate: 5.0000e-06
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 6.3411 - mae: 2.0109 - rmse: 2.5059 - val_loss: 1.2128 - val_mae: 0.8453 - val_rmse: 1.0728 - learning_rate: 5.0000e-06
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - loss: 6.5048 - mae: 2.0232 - rmse: 2.5383 - val_loss: 1.2899 - val_mae: 0.8725 - val_rmse: 1.1082 - learning_rate: 5.0000e-06
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.2351 - mae: 1.9855 - rmse: 2.4846 - val_loss: 1.3258 - val_mae: 0.8906 - val_rmse: 1.1243 - learning_rate: 5.0000e-06
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 6.3918 - mae: 2.0182 - rmse: 2.5160 - val_loss: 1.2496 - val_mae: 0.8623 - val_rmse: 1.0899 - learning_rate: 5.0000e-06
#
# Fold 4 → MAE: 0.8244 | RMSE: 1.0670 | R²: 0.3301
#
# ==================================================
# FOLD 5/5
# ==================================================
# Train size : 1475 | Val size: 73
# HB range   : 8.9 — 16.0 g/dL
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 99s 2s/step - loss: 114.0273 - mae: 10.4815 - rmse: 10.6755 - val_loss: 93.2757 - val_mae: 9.5161 - val_rmse: 9.6547 - learning_rate: 1.0000e-05
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - loss: 55.4139 - mae: 6.9668 - rmse: 7.4399 - val_loss: 29.9327 - val_mae: 5.1584 - val_rmse: 5.4654 - learning_rate: 1.0000e-05
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - loss: 22.0955 - mae: 3.9424 - rmse: 4.6940 - val_loss: 7.6857 - val_mae: 2.1516 - val_rmse: 2.7612 - learning_rate: 1.0000e-05
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 13.1547 - mae: 2.9241 - rmse: 3.6184 - val_loss: 3.5865 - val_mae: 1.4421 - val_rmse: 1.8774 - learning_rate: 1.0000e-05
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 12.6885 - mae: 2.8471 - rmse: 3.5534 - val_loss: 3.0612 - val_mae: 1.3959 - val_rmse: 1.7319 - learning_rate: 1.0000e-05
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 11.5604 - mae: 2.7019 - rmse: 3.3910 - val_loss: 2.8090 - val_mae: 1.3353 - val_rmse: 1.6575 - learning_rate: 1.0000e-05
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 10.9741 - mae: 2.6591 - rmse: 3.3034 - val_loss: 2.5993 - val_mae: 1.3030 - val_rmse: 1.5930 - learning_rate: 1.0000e-05
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 10.0734 - mae: 2.5421 - rmse: 3.1641 - val_loss: 2.4579 - val_mae: 1.2954 - val_rmse: 1.5480 - learning_rate: 1.0000e-05
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 10.1135 - mae: 2.5388 - rmse: 3.1705 - val_loss: 2.2284 - val_mae: 1.1860 - val_rmse: 1.4720 - learning_rate: 1.0000e-05
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 9.7480 - mae: 2.4873 - rmse: 3.1123 - val_loss: 2.0968 - val_mae: 1.1479 - val_rmse: 1.4266 - learning_rate: 1.0000e-05
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 9.3473 - mae: 2.4345 - rmse: 3.0472 - val_loss: 2.0431 - val_mae: 1.1694 - val_rmse: 1.4077 - learning_rate: 1.0000e-05
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 9.4529 - mae: 2.4668 - rmse: 3.0645 - val_loss: 1.9037 - val_mae: 1.0785 - val_rmse: 1.3572 - learning_rate: 1.0000e-05
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 9.1601 - mae: 2.3973 - rmse: 3.0164 - val_loss: 1.8341 - val_mae: 1.0811 - val_rmse: 1.3314 - learning_rate: 1.0000e-05
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 9.5442 - mae: 2.4660 - rmse: 3.0794 - val_loss: 1.7450 - val_mae: 0.9979 - val_rmse: 1.2975 - learning_rate: 1.0000e-05
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 8.9487 - mae: 2.3900 - rmse: 2.9811 - val_loss: 1.6490 - val_mae: 0.9902 - val_rmse: 1.2599 - learning_rate: 1.0000e-05
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 8.1971 - mae: 2.2734 - rmse: 2.8523 - val_loss: 1.5864 - val_mae: 0.9711 - val_rmse: 1.2349 - learning_rate: 1.0000e-05
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 7.7407 - mae: 2.2339 - rmse: 2.7711 - val_loss: 1.5219 - val_mae: 0.9418 - val_rmse: 1.2085 - learning_rate: 1.0000e-05
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - loss: 8.1186 - mae: 2.2683 - rmse: 2.8385 - val_loss: 1.5302 - val_mae: 0.9186 - val_rmse: 1.2119 - learning_rate: 1.0000e-05
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - loss: 8.0837 - mae: 2.2797 - rmse: 2.8323 - val_loss: 1.4100 - val_mae: 0.8989 - val_rmse: 1.1612 - learning_rate: 1.0000e-05
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - loss: 8.0716 - mae: 2.2533 - rmse: 2.8302 - val_loss: 1.4450 - val_mae: 0.8884 - val_rmse: 1.1762 - learning_rate: 1.0000e-05
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - loss: 7.1970 - mae: 2.1343 - rmse: 2.6712 - val_loss: 1.4018 - val_mae: 0.8825 - val_rmse: 1.1577 - learning_rate: 1.0000e-05
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - loss: 7.4140 - mae: 2.1812 - rmse: 2.7116 - val_loss: 1.2681 - val_mae: 0.8488 - val_rmse: 1.0984 - learning_rate: 1.0000e-05
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - loss: 7.0876 - mae: 2.1432 - rmse: 2.6507 - val_loss: 1.2716 - val_mae: 0.8469 - val_rmse: 1.1000 - learning_rate: 1.0000e-05
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - loss: 7.1414 - mae: 2.1235 - rmse: 2.6608 - val_loss: 1.2612 - val_mae: 0.8400 - val_rmse: 1.0953 - learning_rate: 1.0000e-05
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - loss: 6.7163 - mae: 2.0593 - rmse: 2.5797 - val_loss: 1.2632 - val_mae: 0.8452 - val_rmse: 1.0962 - learning_rate: 1.0000e-05
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - loss: 6.9636 - mae: 2.1136 - rmse: 2.6272 - val_loss: 1.2451 - val_mae: 0.8403 - val_rmse: 1.0879 - learning_rate: 1.0000e-05
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - loss: 7.0029 - mae: 2.1024 - rmse: 2.6347 - val_loss: 1.1244 - val_mae: 0.7960 - val_rmse: 1.0310 - learning_rate: 1.0000e-05
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - loss: 6.4514 - mae: 2.0235 - rmse: 2.5278 - val_loss: 1.1729 - val_mae: 0.8138 - val_rmse: 1.0542 - learning_rate: 1.0000e-05
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - loss: 6.5653 - mae: 2.0275 - rmse: 2.5503 - val_loss: 1.1677 - val_mae: 0.8100 - val_rmse: 1.0518 - learning_rate: 1.0000e-05
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - loss: 6.6710 - mae: 2.0441 - rmse: 2.5709 - val_loss: 1.1567 - val_mae: 0.8104 - val_rmse: 1.0466 - learning_rate: 1.0000e-05
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - loss: 6.4378 - mae: 2.0253 - rmse: 2.5251 - val_loss: 1.1412 - val_mae: 0.8096 - val_rmse: 1.0391 - learning_rate: 1.0000e-05
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - loss: 6.4141 - mae: 1.9757 - rmse: 2.5205 - val_loss: 1.1096 - val_mae: 0.7960 - val_rmse: 1.0238 - learning_rate: 1.0000e-05
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 6.5811 - mae: 2.0568 - rmse: 2.5534 - val_loss: 1.1755 - val_mae: 0.8281 - val_rmse: 1.0555 - learning_rate: 5.0000e-06
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 76s 2s/step - loss: 6.6620 - mae: 2.0617 - rmse: 2.5692 - val_loss: 1.0528 - val_mae: 0.7670 - val_rmse: 0.9957 - learning_rate: 5.0000e-06
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - loss: 6.2028 - mae: 1.9751 - rmse: 2.4782 - val_loss: 1.1986 - val_mae: 0.8382 - val_rmse: 1.0664 - learning_rate: 5.0000e-06
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - loss: 6.0216 - mae: 1.9626 - rmse: 2.4414 - val_loss: 1.1389 - val_mae: 0.8116 - val_rmse: 1.0380 - learning_rate: 5.0000e-06
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 6.1214 - mae: 1.9290 - rmse: 2.4617 - val_loss: 1.2048 - val_mae: 0.8377 - val_rmse: 1.0693 - learning_rate: 5.0000e-06
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 6.2854 - mae: 1.9510 - rmse: 2.4948 - val_loss: 1.1203 - val_mae: 0.7967 - val_rmse: 1.0290 - learning_rate: 5.0000e-06
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 5.8450 - mae: 1.9222 - rmse: 2.4049 - val_loss: 1.0519 - val_mae: 0.7667 - val_rmse: 0.9953 - learning_rate: 5.0000e-06
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 5.8845 - mae: 1.9384 - rmse: 2.4131 - val_loss: 1.1623 - val_mae: 0.8204 - val_rmse: 1.0493 - learning_rate: 5.0000e-06
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 5.8702 - mae: 1.9165 - rmse: 2.4102 - val_loss: 1.1486 - val_mae: 0.8134 - val_rmse: 1.0427 - learning_rate: 5.0000e-06
# Epoch 42/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 5.5044 - mae: 1.8844 - rmse: 2.3330 - val_loss: 1.1265 - val_mae: 0.8020 - val_rmse: 1.0321 - learning_rate: 5.0000e-06
# Epoch 43/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 5.6978 - mae: 1.8979 - rmse: 2.3741 - val_loss: 1.0556 - val_mae: 0.7677 - val_rmse: 0.9971 - learning_rate: 5.0000e-06
# Epoch 44/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 5.7891 - mae: 1.9187 - rmse: 2.3933 - val_loss: 1.2268 - val_mae: 0.8467 - val_rmse: 1.0796 - learning_rate: 5.0000e-06
# Epoch 45/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 5.9375 - mae: 1.9502 - rmse: 2.4241 - val_loss: 1.0862 - val_mae: 0.7793 - val_rmse: 1.0123 - learning_rate: 2.5000e-06
# Epoch 46/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 5.8178 - mae: 1.9259 - rmse: 2.3993 - val_loss: 1.1155 - val_mae: 0.7929 - val_rmse: 1.0267 - learning_rate: 2.5000e-06
# Epoch 47/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 5.6477 - mae: 1.8640 - rmse: 2.3635 - val_loss: 1.1460 - val_mae: 0.8084 - val_rmse: 1.0415 - learning_rate: 2.5000e-06
# Epoch 48/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 5.7106 - mae: 1.8945 - rmse: 2.3768 - val_loss: 1.1704 - val_mae: 0.8230 - val_rmse: 1.0531 - learning_rate: 2.5000e-06
# Epoch 49/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 5.8408 - mae: 1.8957 - rmse: 2.4041 - val_loss: 1.1000 - val_mae: 0.7873 - val_rmse: 1.0191 - learning_rate: 2.5000e-06
#
# Fold 5 → MAE: 0.7667 | RMSE: 0.9953 | R²: 0.5649

# %%
# ── K-Fold Summary ───────────────────────────────────────────────
print(f"\n{'='*50}")
print("K-FOLD SUMMARY — EfficientNetB0 Regression")
print(f"{'='*50}")

maes  = [r["mae"]  for r in fold_results]
rmses = [r["rmse"] for r in fold_results]
r2s   = [r["r2"]   for r in fold_results]

for r in fold_results:
    print(f"Fold {r['fold']} → MAE: {r['mae']:.4f} | RMSE: {r['rmse']:.4f} | R²: {r['r2']:.4f}")

print(f"\nMean MAE  : {np.mean(maes):.4f} ± {np.std(maes):.4f}")
print(f"Mean RMSE : {np.mean(rmses):.4f} ± {np.std(rmses):.4f}")
print(f"Mean R²   : {np.mean(r2s):.4f} ± {np.std(r2s):.4f}")

# ── Best fold ────────────────────────────────────────────────────
best_fold  = fold_results[np.argmin(maes)]
best_model = best_fold["model"]
print(f"\n✅ Best Fold: {best_fold['fold']} (MAE={best_fold['mae']:.4f})")

# ── Test set evaluation ──────────────────────────────────────────
y_hb_pred_test = best_model.predict(
    [X_palm_test, X_nail_test, X_meta_test], verbose=0
).ravel()

print(f"\n{'='*50}")
print("FINAL TEST RESULTS — EfficientNetB0 Regression")
print(f"{'='*50}")
print(f"MAE  : {mean_absolute_error(y_hb_test, y_hb_pred_test):.4f} g/dL")
print(f"RMSE : {np.sqrt(mean_squared_error(y_hb_test, y_hb_pred_test)):.4f} g/dL")
print(f"R²   : {r2_score(y_hb_test, y_hb_pred_test):.4f}")

# ── Plots ────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle("EfficientNetB0 Regression — K-Fold", fontsize=14, fontweight="bold")

# Plot 1 - MAE per fold
axes[0].bar([r["fold"] for r in fold_results], maes, color="steelblue", edgecolor="black")
axes[0].axhline(np.mean(maes), color="red", linestyle="--", label=f"Mean MAE: {np.mean(maes):.4f}")
axes[0].set_title("MAE per Fold")
axes[0].set_xlabel("Fold")
axes[0].set_ylabel("MAE (g/dL)")
axes[0].legend()
axes[0].grid(axis="y", alpha=0.3)

# Plot 2 - R² per fold
axes[1].bar([r["fold"] for r in fold_results], r2s, color="darkorange", edgecolor="black")
axes[1].axhline(np.mean(r2s), color="red", linestyle="--", label=f"Mean R²: {np.mean(r2s):.4f}")
axes[1].set_title("R² per Fold")
axes[1].set_xlabel("Fold")
axes[1].set_ylabel("R²")
axes[1].legend()
axes[1].grid(axis="y", alpha=0.3)

# Plot 3 - Predicted vs Actual on test set
axes[2].scatter(y_hb_test, y_hb_pred_test, alpha=0.6, color="steelblue")
axes[2].plot([y_hb_test.min(), y_hb_test.max()],
             [y_hb_test.min(), y_hb_test.max()],
             "r--", lw=2, label="Perfect prediction")
axes[2].set_title(f"Predicted vs Actual HB\n(R²={r2_score(y_hb_test, y_hb_pred_test):.3f})")
axes[2].set_xlabel("Actual HB (g/dL)")
axes[2].set_ylabel("Predicted HB (g/dL)")
axes[2].legend()
axes[2].grid(True)

plt.tight_layout()
plt.show()
# Out:
# ==================================================
# K-FOLD SUMMARY — EfficientNetB0 Regression
# ==================================================
# Fold 1 → MAE: 0.8249 | RMSE: 0.9968 | R²: 0.4445
# Fold 2 → MAE: 0.6679 | RMSE: 0.8274 | R²: 0.5060
# Fold 3 → MAE: 0.8043 | RMSE: 1.0129 | R²: 0.5169
# Fold 4 → MAE: 0.8244 | RMSE: 1.0670 | R²: 0.3301
# Fold 5 → MAE: 0.7667 | RMSE: 0.9953 | R²: 0.5649
#
# Mean MAE  : 0.7776 ± 0.0588
# Mean RMSE : 0.9799 ± 0.0806
# Mean R²   : 0.4725 ± 0.0809
#
# ✅ Best Fold: 2 (MAE=0.6679)
#
# ==================================================
# FINAL TEST RESULTS — EfficientNetB0 Regression
# ==================================================
# MAE  : 0.7955 g/dL
# RMSE : 0.9984 g/dL
# R²   : 0.4576

# %% [markdown]
# # HB Normalized

# %%
# ── Normalize HB target ──────────────────────────────────────────
hb_mean = y_hb_train.mean()
hb_std  = y_hb_train.std()

y_hb_train_norm = (y_hb_train - hb_mean) / hb_std
y_hb_val_norm   = (y_hb_val   - hb_mean) / hb_std
y_hb_test_norm  = (y_hb_test  - hb_mean) / hb_std

print(f"HB mean : {hb_mean:.4f} | HB std : {hb_std:.4f}")
# Out:
# HB mean : 12.2889 | HB std : 1.3660

# %%
history_reg = model_4_REG.fit(
    x               = [X_palm_train, X_nail_train, X_meta_train],
    y               = y_hb_train_norm,
    validation_data = ([X_palm_val, X_nail_val, X_meta_val], y_hb_val_norm),
    epochs=100, batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - loss: 0.8094 - mae: 1.1605 - rmse: 1.4360 - val_loss: 0.6895 - val_mae: 1.0650 - val_rmse: 1.2052 - learning_rate: 1.0000e-06
# Epoch 2/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 0.7222 - mae: 1.0709 - rmse: 1.3195 - val_loss: 0.6831 - val_mae: 1.0473 - val_rmse: 1.2224 - learning_rate: 1.0000e-06
# Epoch 3/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - loss: 0.6971 - mae: 1.0365 - rmse: 1.2924 - val_loss: 0.6767 - val_mae: 1.0277 - val_rmse: 1.2354 - learning_rate: 1.0000e-06
# Epoch 4/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - loss: 0.6469 - mae: 0.9846 - rmse: 1.2246 - val_loss: 0.6506 - val_mae: 0.9838 - val_rmse: 1.2186 - learning_rate: 1.0000e-06
# Epoch 5/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.6412 - mae: 0.9732 - rmse: 1.2210 - val_loss: 0.6277 - val_mae: 0.9476 - val_rmse: 1.2038 - learning_rate: 1.0000e-06
# Epoch 6/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.6043 - mae: 0.9323 - rmse: 1.1743 - val_loss: 0.6130 - val_mae: 0.9265 - val_rmse: 1.1965 - learning_rate: 1.0000e-06
# Epoch 7/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.6041 - mae: 0.9358 - rmse: 1.1732 - val_loss: 0.6009 - val_mae: 0.9132 - val_rmse: 1.1863 - learning_rate: 1.0000e-06
# Epoch 8/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - loss: 0.6003 - mae: 0.9295 - rmse: 1.1678 - val_loss: 0.5897 - val_mae: 0.9013 - val_rmse: 1.1727 - learning_rate: 1.0000e-06
# Epoch 9/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.5702 - mae: 0.8982 - rmse: 1.1181 - val_loss: 0.5785 - val_mae: 0.8894 - val_rmse: 1.1565 - learning_rate: 1.0000e-06
# Epoch 10/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.5619 - mae: 0.8843 - rmse: 1.1108 - val_loss: 0.5685 - val_mae: 0.8777 - val_rmse: 1.1436 - learning_rate: 1.0000e-06
# Epoch 11/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - loss: 0.5235 - mae: 0.8406 - rmse: 1.0625 - val_loss: 0.5585 - val_mae: 0.8681 - val_rmse: 1.1278 - learning_rate: 1.0000e-06
# Epoch 12/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.5426 - mae: 0.8597 - rmse: 1.0846 - val_loss: 0.5503 - val_mae: 0.8602 - val_rmse: 1.1149 - learning_rate: 1.0000e-06
# Epoch 13/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.5477 - mae: 0.8667 - rmse: 1.0935 - val_loss: 0.5432 - val_mae: 0.8528 - val_rmse: 1.1038 - learning_rate: 1.0000e-06
# Epoch 14/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.5557 - mae: 0.8776 - rmse: 1.1004 - val_loss: 0.5382 - val_mae: 0.8474 - val_rmse: 1.0965 - learning_rate: 1.0000e-06
# Epoch 15/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.5265 - mae: 0.8432 - rmse: 1.0687 - val_loss: 0.5312 - val_mae: 0.8420 - val_rmse: 1.0844 - learning_rate: 1.0000e-06
# Epoch 16/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.5373 - mae: 0.8562 - rmse: 1.0764 - val_loss: 0.5255 - val_mae: 0.8369 - val_rmse: 1.0741 - learning_rate: 1.0000e-06
# Epoch 17/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 0.5112 - mae: 0.8268 - rmse: 1.0415 - val_loss: 0.5212 - val_mae: 0.8317 - val_rmse: 1.0676 - learning_rate: 1.0000e-06
# Epoch 18/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4987 - mae: 0.8116 - rmse: 1.0252 - val_loss: 0.5164 - val_mae: 0.8252 - val_rmse: 1.0624 - learning_rate: 1.0000e-06
# Epoch 19/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.5119 - mae: 0.8297 - rmse: 1.0425 - val_loss: 0.5118 - val_mae: 0.8190 - val_rmse: 1.0559 - learning_rate: 1.0000e-06
# Epoch 20/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.5009 - mae: 0.8120 - rmse: 1.0302 - val_loss: 0.5072 - val_mae: 0.8131 - val_rmse: 1.0493 - learning_rate: 1.0000e-06
# Epoch 21/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.5056 - mae: 0.8137 - rmse: 1.0410 - val_loss: 0.5021 - val_mae: 0.8088 - val_rmse: 1.0411 - learning_rate: 1.0000e-06
# Epoch 22/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4856 - mae: 0.7976 - rmse: 1.0015 - val_loss: 0.4971 - val_mae: 0.8031 - val_rmse: 1.0319 - learning_rate: 1.0000e-06
# Epoch 23/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4777 - mae: 0.7847 - rmse: 0.9967 - val_loss: 0.4915 - val_mae: 0.7973 - val_rmse: 1.0230 - learning_rate: 1.0000e-06
# Epoch 24/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4701 - mae: 0.7792 - rmse: 0.9832 - val_loss: 0.4882 - val_mae: 0.7926 - val_rmse: 1.0196 - learning_rate: 1.0000e-06
# Epoch 25/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4688 - mae: 0.7771 - rmse: 0.9764 - val_loss: 0.4853 - val_mae: 0.7892 - val_rmse: 1.0157 - learning_rate: 1.0000e-06
# Epoch 26/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4705 - mae: 0.7769 - rmse: 0.9817 - val_loss: 0.4802 - val_mae: 0.7854 - val_rmse: 1.0073 - learning_rate: 1.0000e-06
# Epoch 27/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4744 - mae: 0.7827 - rmse: 0.9869 - val_loss: 0.4774 - val_mae: 0.7819 - val_rmse: 1.0033 - learning_rate: 1.0000e-06
# Epoch 28/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4648 - mae: 0.7738 - rmse: 0.9689 - val_loss: 0.4762 - val_mae: 0.7803 - val_rmse: 1.0019 - learning_rate: 1.0000e-06
# Epoch 29/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4597 - mae: 0.7616 - rmse: 0.9672 - val_loss: 0.4720 - val_mae: 0.7760 - val_rmse: 0.9938 - learning_rate: 1.0000e-06
# Epoch 30/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4483 - mae: 0.7563 - rmse: 0.9459 - val_loss: 0.4700 - val_mae: 0.7730 - val_rmse: 0.9911 - learning_rate: 1.0000e-06
# Epoch 31/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4411 - mae: 0.7450 - rmse: 0.9398 - val_loss: 0.4675 - val_mae: 0.7696 - val_rmse: 0.9881 - learning_rate: 1.0000e-06
# Epoch 32/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4445 - mae: 0.7394 - rmse: 0.9481 - val_loss: 0.4616 - val_mae: 0.7633 - val_rmse: 0.9773 - learning_rate: 1.0000e-06
# Epoch 33/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4260 - mae: 0.7229 - rmse: 0.9187 - val_loss: 0.4611 - val_mae: 0.7622 - val_rmse: 0.9775 - learning_rate: 1.0000e-06
# Epoch 34/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4280 - mae: 0.7285 - rmse: 0.9223 - val_loss: 0.4572 - val_mae: 0.7571 - val_rmse: 0.9716 - learning_rate: 1.0000e-06
# Epoch 35/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4311 - mae: 0.7299 - rmse: 0.9210 - val_loss: 0.4537 - val_mae: 0.7529 - val_rmse: 0.9656 - learning_rate: 1.0000e-06
# Epoch 36/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4283 - mae: 0.7309 - rmse: 0.9197 - val_loss: 0.4507 - val_mae: 0.7483 - val_rmse: 0.9612 - learning_rate: 1.0000e-06
# Epoch 37/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4234 - mae: 0.7181 - rmse: 0.9180 - val_loss: 0.4476 - val_mae: 0.7444 - val_rmse: 0.9569 - learning_rate: 1.0000e-06
# Epoch 38/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4268 - mae: 0.7256 - rmse: 0.9199 - val_loss: 0.4440 - val_mae: 0.7399 - val_rmse: 0.9517 - learning_rate: 1.0000e-06
# Epoch 39/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4210 - mae: 0.7238 - rmse: 0.9067 - val_loss: 0.4394 - val_mae: 0.7341 - val_rmse: 0.9446 - learning_rate: 1.0000e-06
# Epoch 40/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4199 - mae: 0.7179 - rmse: 0.9077 - val_loss: 0.4358 - val_mae: 0.7295 - val_rmse: 0.9378 - learning_rate: 1.0000e-06
# Epoch 41/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4135 - mae: 0.7064 - rmse: 0.8994 - val_loss: 0.4343 - val_mae: 0.7265 - val_rmse: 0.9365 - learning_rate: 1.0000e-06
# Epoch 42/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 0.4040 - mae: 0.6966 - rmse: 0.8885 - val_loss: 0.4310 - val_mae: 0.7220 - val_rmse: 0.9321 - learning_rate: 1.0000e-06
# Epoch 43/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.4082 - mae: 0.7048 - rmse: 0.8950 - val_loss: 0.4287 - val_mae: 0.7187 - val_rmse: 0.9279 - learning_rate: 1.0000e-06
# Epoch 44/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - loss: 0.4108 - mae: 0.7053 - rmse: 0.8935 - val_loss: 0.4266 - val_mae: 0.7158 - val_rmse: 0.9252 - learning_rate: 1.0000e-06
# Epoch 45/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - loss: 0.4027 - mae: 0.6966 - rmse: 0.8839 - val_loss: 0.4237 - val_mae: 0.7114 - val_rmse: 0.9215 - learning_rate: 1.0000e-06
# Epoch 46/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 0.4037 - mae: 0.6967 - rmse: 0.8828 - val_loss: 0.4225 - val_mae: 0.7094 - val_rmse: 0.9205 - learning_rate: 1.0000e-06
# Epoch 47/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - loss: 0.3950 - mae: 0.6897 - rmse: 0.8666 - val_loss: 0.4177 - val_mae: 0.7047 - val_rmse: 0.9124 - learning_rate: 1.0000e-06
# Epoch 48/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - loss: 0.3926 - mae: 0.6848 - rmse: 0.8701 - val_loss: 0.4158 - val_mae: 0.7027 - val_rmse: 0.9086 - learning_rate: 1.0000e-06
# Epoch 49/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - loss: 0.3973 - mae: 0.6942 - rmse: 0.8672 - val_loss: 0.4151 - val_mae: 0.7015 - val_rmse: 0.9081 - learning_rate: 1.0000e-06
# Epoch 50/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3918 - mae: 0.6825 - rmse: 0.8664 - val_loss: 0.4136 - val_mae: 0.7002 - val_rmse: 0.9061 - learning_rate: 1.0000e-06
# Epoch 51/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3861 - mae: 0.6773 - rmse: 0.8522 - val_loss: 0.4098 - val_mae: 0.6952 - val_rmse: 0.8999 - learning_rate: 1.0000e-06
# Epoch 52/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3922 - mae: 0.6823 - rmse: 0.8679 - val_loss: 0.4082 - val_mae: 0.6936 - val_rmse: 0.8974 - learning_rate: 1.0000e-06
# Epoch 53/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.3782 - mae: 0.6678 - rmse: 0.8420 - val_loss: 0.4033 - val_mae: 0.6876 - val_rmse: 0.8898 - learning_rate: 1.0000e-06
# Epoch 54/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3764 - mae: 0.6649 - rmse: 0.8427 - val_loss: 0.4020 - val_mae: 0.6853 - val_rmse: 0.8881 - learning_rate: 1.0000e-06
# Epoch 55/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3805 - mae: 0.6664 - rmse: 0.8455 - val_loss: 0.4007 - val_mae: 0.6836 - val_rmse: 0.8860 - learning_rate: 1.0000e-06
# Epoch 56/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3853 - mae: 0.6774 - rmse: 0.8539 - val_loss: 0.4002 - val_mae: 0.6826 - val_rmse: 0.8856 - learning_rate: 1.0000e-06
# Epoch 57/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3779 - mae: 0.6682 - rmse: 0.8459 - val_loss: 0.4012 - val_mae: 0.6836 - val_rmse: 0.8874 - learning_rate: 1.0000e-06
# Epoch 58/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3784 - mae: 0.6652 - rmse: 0.8468 - val_loss: 0.3983 - val_mae: 0.6791 - val_rmse: 0.8829 - learning_rate: 1.0000e-06
# Epoch 59/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3830 - mae: 0.6705 - rmse: 0.8521 - val_loss: 0.3954 - val_mae: 0.6760 - val_rmse: 0.8774 - learning_rate: 1.0000e-06
# Epoch 60/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3838 - mae: 0.6778 - rmse: 0.8545 - val_loss: 0.3921 - val_mae: 0.6732 - val_rmse: 0.8719 - learning_rate: 1.0000e-06
# Epoch 61/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3726 - mae: 0.6573 - rmse: 0.8390 - val_loss: 0.3922 - val_mae: 0.6738 - val_rmse: 0.8721 - learning_rate: 1.0000e-06
# Epoch 62/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3761 - mae: 0.6635 - rmse: 0.8445 - val_loss: 0.3921 - val_mae: 0.6737 - val_rmse: 0.8722 - learning_rate: 1.0000e-06
# Epoch 63/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3668 - mae: 0.6513 - rmse: 0.8266 - val_loss: 0.3907 - val_mae: 0.6719 - val_rmse: 0.8698 - learning_rate: 1.0000e-06
# Epoch 64/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.3537 - mae: 0.6337 - rmse: 0.8062 - val_loss: 0.3893 - val_mae: 0.6706 - val_rmse: 0.8674 - learning_rate: 1.0000e-06
# Epoch 65/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3622 - mae: 0.6442 - rmse: 0.8228 - val_loss: 0.3884 - val_mae: 0.6688 - val_rmse: 0.8665 - learning_rate: 1.0000e-06
# Epoch 66/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3558 - mae: 0.6373 - rmse: 0.8083 - val_loss: 0.3869 - val_mae: 0.6663 - val_rmse: 0.8646 - learning_rate: 1.0000e-06
# Epoch 67/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.3643 - mae: 0.6528 - rmse: 0.8182 - val_loss: 0.3865 - val_mae: 0.6659 - val_rmse: 0.8634 - learning_rate: 1.0000e-06
# Epoch 68/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3596 - mae: 0.6384 - rmse: 0.8185 - val_loss: 0.3846 - val_mae: 0.6650 - val_rmse: 0.8597 - learning_rate: 1.0000e-06
# Epoch 69/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.3522 - mae: 0.6334 - rmse: 0.8038 - val_loss: 0.3821 - val_mae: 0.6629 - val_rmse: 0.8553 - learning_rate: 1.0000e-06
# Epoch 70/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 0.3595 - mae: 0.6454 - rmse: 0.8129 - val_loss: 0.3828 - val_mae: 0.6633 - val_rmse: 0.8565 - learning_rate: 1.0000e-06
# Epoch 71/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3586 - mae: 0.6447 - rmse: 0.8123 - val_loss: 0.3826 - val_mae: 0.6628 - val_rmse: 0.8564 - learning_rate: 1.0000e-06
# Epoch 72/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3535 - mae: 0.6320 - rmse: 0.8038 - val_loss: 0.3828 - val_mae: 0.6632 - val_rmse: 0.8566 - learning_rate: 1.0000e-06
# Epoch 73/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3504 - mae: 0.6304 - rmse: 0.8038 - val_loss: 0.3828 - val_mae: 0.6626 - val_rmse: 0.8571 - learning_rate: 1.0000e-06
# Epoch 74/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3467 - mae: 0.6265 - rmse: 0.7982 - val_loss: 0.3832 - val_mae: 0.6629 - val_rmse: 0.8584 - learning_rate: 1.0000e-06
# Epoch 75/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3513 - mae: 0.6341 - rmse: 0.7983 - val_loss: 0.3817 - val_mae: 0.6610 - val_rmse: 0.8557 - learning_rate: 1.0000e-06
# Epoch 76/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3531 - mae: 0.6385 - rmse: 0.8044 - val_loss: 0.3778 - val_mae: 0.6588 - val_rmse: 0.8482 - learning_rate: 1.0000e-06
# Epoch 77/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.3500 - mae: 0.6315 - rmse: 0.7990 - val_loss: 0.3753 - val_mae: 0.6560 - val_rmse: 0.8444 - learning_rate: 1.0000e-06
# Epoch 78/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3380 - mae: 0.6132 - rmse: 0.7799 - val_loss: 0.3756 - val_mae: 0.6550 - val_rmse: 0.8463 - learning_rate: 1.0000e-06
# Epoch 79/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3526 - mae: 0.6315 - rmse: 0.8034 - val_loss: 0.3742 - val_mae: 0.6549 - val_rmse: 0.8429 - learning_rate: 1.0000e-06
# Epoch 80/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3265 - mae: 0.5961 - rmse: 0.7670 - val_loss: 0.3730 - val_mae: 0.6538 - val_rmse: 0.8406 - learning_rate: 1.0000e-06
# Epoch 81/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.3411 - mae: 0.6161 - rmse: 0.7854 - val_loss: 0.3734 - val_mae: 0.6539 - val_rmse: 0.8416 - learning_rate: 1.0000e-06
# Epoch 82/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3332 - mae: 0.6073 - rmse: 0.7732 - val_loss: 0.3737 - val_mae: 0.6540 - val_rmse: 0.8425 - learning_rate: 1.0000e-06
# Epoch 83/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3442 - mae: 0.6227 - rmse: 0.7915 - val_loss: 0.3747 - val_mae: 0.6550 - val_rmse: 0.8436 - learning_rate: 1.0000e-06
# Epoch 84/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3460 - mae: 0.6272 - rmse: 0.7891 - val_loss: 0.3736 - val_mae: 0.6553 - val_rmse: 0.8411 - learning_rate: 1.0000e-06
# Epoch 85/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3345 - mae: 0.6101 - rmse: 0.7761 - val_loss: 0.3711 - val_mae: 0.6539 - val_rmse: 0.8367 - learning_rate: 1.0000e-06
# Epoch 86/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3492 - mae: 0.6272 - rmse: 0.7995 - val_loss: 0.3713 - val_mae: 0.6533 - val_rmse: 0.8372 - learning_rate: 1.0000e-06
# Epoch 87/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3305 - mae: 0.6029 - rmse: 0.7701 - val_loss: 0.3711 - val_mae: 0.6531 - val_rmse: 0.8370 - learning_rate: 1.0000e-06
# Epoch 88/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3310 - mae: 0.6033 - rmse: 0.7730 - val_loss: 0.3691 - val_mae: 0.6516 - val_rmse: 0.8332 - learning_rate: 1.0000e-06
# Epoch 89/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3400 - mae: 0.6171 - rmse: 0.7826 - val_loss: 0.3688 - val_mae: 0.6505 - val_rmse: 0.8328 - learning_rate: 1.0000e-06
# Epoch 90/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3257 - mae: 0.5986 - rmse: 0.7614 - val_loss: 0.3687 - val_mae: 0.6496 - val_rmse: 0.8336 - learning_rate: 1.0000e-06
# Epoch 91/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.3266 - mae: 0.5981 - rmse: 0.7652 - val_loss: 0.3684 - val_mae: 0.6494 - val_rmse: 0.8328 - learning_rate: 1.0000e-06
# Epoch 92/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3177 - mae: 0.5840 - rmse: 0.7503 - val_loss: 0.3671 - val_mae: 0.6477 - val_rmse: 0.8304 - learning_rate: 1.0000e-06
# Epoch 93/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.3283 - mae: 0.5991 - rmse: 0.7693 - val_loss: 0.3669 - val_mae: 0.6484 - val_rmse: 0.8294 - learning_rate: 1.0000e-06
# Epoch 94/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3290 - mae: 0.6090 - rmse: 0.7628 - val_loss: 0.3678 - val_mae: 0.6505 - val_rmse: 0.8307 - learning_rate: 1.0000e-06
# Epoch 95/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3178 - mae: 0.5876 - rmse: 0.7468 - val_loss: 0.3661 - val_mae: 0.6480 - val_rmse: 0.8281 - learning_rate: 1.0000e-06
# Epoch 96/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - loss: 0.3375 - mae: 0.6156 - rmse: 0.7781 - val_loss: 0.3679 - val_mae: 0.6491 - val_rmse: 0.8315 - learning_rate: 1.0000e-06
# Epoch 97/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3253 - mae: 0.5972 - rmse: 0.7600 - val_loss: 0.3682 - val_mae: 0.6495 - val_rmse: 0.8319 - learning_rate: 1.0000e-06
# Epoch 98/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3307 - mae: 0.6075 - rmse: 0.7698 - val_loss: 0.3646 - val_mae: 0.6470 - val_rmse: 0.8255 - learning_rate: 1.0000e-06
# Epoch 99/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - loss: 0.3230 - mae: 0.5960 - rmse: 0.7560 - val_loss: 0.3657 - val_mae: 0.6471 - val_rmse: 0.8279 - learning_rate: 1.0000e-06
# Epoch 100/100
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.3159 - mae: 0.5910 - rmse: 0.7439 - val_loss: 0.3639 - val_mae: 0.6468 - val_rmse: 0.8241 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 100.

# %%
# predict and denormalize
y_pred_norm   = model_4_REG.predict([X_palm_test, X_nail_test, X_meta_test], verbose=0).ravel()
y_pred_actual = (y_pred_norm * hb_std) + hb_mean  # ← back to g/dL

# evaluate on actual values
print(f"MAE  : {mean_absolute_error(y_hb_test, y_pred_actual):.4f} g/dL")
print(f"RMSE : {np.sqrt(mean_squared_error(y_hb_test, y_pred_actual)):.4f} g/dL")
print(f"R²   : {r2_score(y_hb_test, y_pred_actual):.4f}")

# scatter plot
plt.figure(figsize=(6, 5))
plt.scatter(y_hb_test, y_pred_actual, alpha=0.6, color="steelblue")
plt.plot([y_hb_test.min(), y_hb_test.max()],
         [y_hb_test.min(), y_hb_test.max()],
         "r--", lw=2, label="Perfect prediction")
plt.title(f"Predicted vs Actual HB")
plt.xlabel("Actual HB (g/dL)")
plt.ylabel("Predicted HB (g/dL)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000013A143599E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000013A143599E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MAE  : 0.7986 g/dL
# RMSE : 0.9801 g/dL
# R²   : 0.4772
